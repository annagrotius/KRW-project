# %% [markdown]
# # Requirements
#
# 1. Input folder
# 2. HypythesisInstances.ttl
# 3. PaperInstances.ttl
# 4. ProvenanceInstances.ttl

# %%
import sys

from rdflib import Graph, ConjunctiveGraph, Literal, BNode, Namespace, RDF, URIRef
from rdflib.namespace import DC, FOAF
import pprint

input_directory = "../Input/"
hypothesis_instances = "HypothesisInstances2.ttl"
paper_instances = "paper_abs_instances.ttl"
provenance_instances = "provenance_instances_new.ttl"

hyp_inst_g = Graph()
hyp_inst_g.parse(input_directory+hypothesis_instances, format='turtle')

pap_inst_g = Graph()
pap_inst_g.parse(input_directory+paper_instances, format='turtle')

pro_inst_g = Graph()
pro_inst_g.parse(input_directory+provenance_instances, format='turtle')

merged_graph = hyp_inst_g + pro_inst_g + pap_inst_g

# %%
# for stmt in merged_graph:
#     pprint.pprint(stmt)

# %%
f = open("hypothesis_graph.nt", "w")
f.write(merged_graph.serialize(format='nt').decode())
f.close()

# %%
# You can also parse directly from a string
g = Graph()
g.parse("hypothesis_graph.nt", format="nt")

bibo_uri = URIRef("http://purl.org/ontology/bibo/")
bibo_namespace = Namespace(bibo_uri)
g.bind("bibo", bibo_namespace)

dct_uri = URIRef("http://purl.org/dc/terms/")
dct_namespace = Namespace(dct_uri)
g.bind("dct", dct_namespace)

fabio_uri = URIRef("http://purl.org/spar/fabio/")
fabio_namespace = Namespace(fabio_uri)
g.bind("fabio", fabio_namespace)

foaf_uri = URIRef("http://xmlns.com/foaf/0.1/")
foaf_namespace = Namespace(foaf_uri)
g.bind("foaf", foaf_namespace)

oa_uri = URIRef("http://www.w3.org/ns/oa#")
oa_namespace = Namespace(oa_uri)
g.bind("oa", oa_namespace)

schema_uri = URIRef("http://schema.org/")
schema_namespace = Namespace(schema_uri)
g.bind("schema", schema_namespace)

hyp_uri = URIRef("http://example.org/hypothesis_ontology/")
hyp_namespace = Namespace(hyp_uri)
g.bind("hyp", hyp_namespace)

# print(g.serialize("../Output-Graphs/hypothesis_graph2.ttl", format='turtle').decode())
g.serialize("../Output-Graphs/hypothesis_graph4.ttl", format='turtle')

# %%
# f = open("../Output-Graphs/hypothesis_graph2.ttl", "w")
# f.write(g.serialize(format='turtle').decode())
# f.close()

# %% [markdown]
# ## Saving RDF graphs
#
# We use the function Graph.serialize(format)

# %%
g = Graph()
g.parse("demo.nt", format='n3')
# for a,b,c in g:
#     print(a,b,c)

print(g.serialize(format='nt').decode()) # 'html', 'hturtle', 'mdata', 'microdata', 'n3', 'nquads', 'nt', 'rdfa', 'rdfa1.0', 'rdfa1.1', 'trix', 'turtle', 'xml'
# Out:
# <http://bigasterisk.com/foaf.rdf#drewp> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://xmlns.com/foaf/0.1/Person> .
# <http://bigasterisk.com/foaf.rdf#drewp> <http://example.com/says> "Hello world" .

# %% [markdown]
# ##  Merging graphs
#
# Merging graphs can be done via sequential parsings or by the overloaded operator +
#
# **Note:** Set-theoretic graph semantics apply

# %%
graph = Graph()

# Sequential parsings merge *new* triples

graph.parse("demo.nt", format='nt')
graph.parse("demo.xml", format='xml')

print("Graph has {} triples".format(len(graph)))
# Out:
# Graph has 2 triples

# %%
g1 = Graph()
g1.parse("demo.nt", format='nt')
print("g1 has {} triples".format(len(g1)))

g2 = Graph()
g2.parse("demo.xml", format='xml')
print("g2 has {} triples".format(len(g2)))

graph = g1 + g2
print("g1 + g2 has {} triples".format(len(graph)))
# Out:
# g1 has 2 triples
# g2 has 2 triples
# g1 + g2 has 2 triples

# %%
# Now, if we merge graphs with different contents

tim_g = Graph()
tim_g.parse("http://www.w3.org/People/Berners-Lee/card")
print("Tim graph has {} triples".format(len(tim_g)))

g3 = g1 + tim_g
print("g3 has {} triples".format(len(g3)))
# Out:
# Tim graph has 86 triples
# g3 has 88 triples

# %% [markdown]
# ## Creating RDF triples
#
# Triples are added to the graph with the function Graph.add()
#
# The parameter is a triple given in a Python **tuple** (subject, predicate, object)
#
# Notice the namespace convenience syntax!

# %%
g = Graph()

# Create an identifier to use as the subject for Donna.
donna = BNode()
# donna = URIRef("http://example.org/donna")

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

for i in range(100):
    g.add((donna, FOAF.hadAge, Literal(i)))

print(len(g))

for s in g:
    pprint.pprint(s)
    print()
# Out:
# 104
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('79', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('39', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('84', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('15', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('35', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('81', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('99', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('92', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('32', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('96', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('52', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('59', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('55', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('17', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('77', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('30', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('28', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('27', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('53', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('18', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('44', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('50', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('47', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('71', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('78', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('93', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('41', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('33', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('49', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'),
#  rdflib.term.Literal('Donna Fales'))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/mbox'),
#  rdflib.term.URIRef('mailto:donna@example.org'))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('14', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('21', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('57', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('29', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('20', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('62', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('56', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('91', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('83', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('43', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('16', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('23', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('31', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('61', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('76', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('94', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('25', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('24', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('98', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('64', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('82', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('58', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('69', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('22', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('38', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('46', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('73', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('68', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('51', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('89', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('86', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('36', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('63', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('34', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/nick'),
#  rdflib.term.Literal('donna', lang='foo'))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('97', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('67', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('60', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('19', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('54', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('87', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('48', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('37', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('26', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('45', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
#
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'),
#  rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'),
#  rdflib.term.Literal('88', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %%
for stmt in g:
    print(stmt)
# Out:
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('79', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('39', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('66', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('84', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('15', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('35', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('81', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('72', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('99', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('92', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('32', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('96', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('52', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('59', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('55', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('17', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('77', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('30', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('5', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('2', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('28', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('3', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('27', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('53', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('18', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('95', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('11', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('44', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('50', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('47', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('71', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('78', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('40', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('93', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('41', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('90', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('33', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('49', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'), rdflib.term.Literal('Donna Fales'))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/mbox'), rdflib.term.URIRef('mailto:donna@example.org'))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('8', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('14', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('21', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('57', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('29', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('20', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('62', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('65', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('56', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('91', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('12', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('83', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('43', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('7', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('16', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('23', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('31', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('61', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('76', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('94', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('25', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('85', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('24', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('98', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('80', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('64', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('82', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('58', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('69', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('22', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('38', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('46', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('73', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('74', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('9', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('68', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('51', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('89', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('13', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('86', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('36', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('63', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('34', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/nick'), rdflib.term.Literal('donna', lang='foo'))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('70', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('97', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('10', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('67', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('60', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('19', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('54', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('87', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('75', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('48', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('37', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('26', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('45', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd18bb9b74e0e40cc865d314fd4514240'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/hadAge'), rdflib.term.Literal('88', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))

# %%
print(FOAF.Person)
# Out:
# http://xmlns.com/foaf/0.1/Person

# %%
print(FOAF.imadethisup)
# Out:
# http://xmlns.com/foaf/0.1/imadethisup

# %% [markdown]
# ## Navigating graphs
#
# rdflib uses iterators to navigate Graphs. The methods for navigating subjects, predicates and objects are Graph.subjects, Graph.predicates, Graph.objects

# %%
g = Graph()
g.parse("http://www.w3.org/People/Berners-Lee/card")

# Iterate over triples in store and print them out.
print("--- printing raw triples ---")
for s, p, o in g:
    print(p)
# Out:
# --- printing raw triples ---
# http://xmlns.com/foaf/0.1/nick
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2006/vcard/ns#region
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://www.w3.org/2000/10/swap/pim/contact#preferredURI
# http://www.w3.org/ns/auth/cert#exponent
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/ns/solid/terms#profileBackgroundColor
# http://www.w3.org/ns/solid/terms#editableProfile
# http://www.w3.org/2006/vcard/ns#postal-code
# http://xmlns.com/foaf/0.1/member
# http://www.w3.org/2000/10/swap/pim/contact#street
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://xmlns.com/foaf/0.1/primaryTopic
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://purl.org/dc/terms/title
# http://www.w3.org/2000/01/rdf-schema#label
# http://xmlns.com/foaf/0.1/maker
# http://purl.org/dc/elements/1.1/title
# http://creativecommons.org/ns#license
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/account
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#street2
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/workplaceHomepage
# http://xmlns.com/foaf/0.1/name
# http://usefulinc.com/ns/doap#developer
# http://www.w3.org/2000/10/swap/pim/contact#assistant
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://creativecommons.org/ns#license
# http://schema.org/owns
# http://www.w3.org/2000/10/swap/pim/contact#office
# http://xmlns.com/foaf/0.1/primaryTopic
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/2000/10/swap/pim/contact#country
# http://xmlns.com/foaf/0.1/title
# http://rdfs.org/sioc/ns#avatar
# http://www.w3.org/2006/vcard/ns#locality
# http://www.w3.org/2006/vcard/ns#hasAddress
# http://xmlns.com/foaf/0.1/member
# http://www.w3.org/ns/solid/terms#publicTypeIndex
# http://usefulinc.com/ns/doap#developer
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/10/swap/pim/contact#address
# http://www.w3.org/ns/solid/terms#profileHighlightColor
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://xmlns.com/foaf/0.1/mbox_sha1sum
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/10/swap/pim/contact#publicHomePage
# http://www.w3.org/2000/10/swap/pim/contact#city
# http://www.w3.org/2003/01/geo/wgs84_pos#location
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/2006/vcard/ns#street-address
# http://www.w3.org/ns/auth/cert#key
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/ns/pim/space#preferencesFile
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/mbox
# http://www.w3.org/ns/ldp#inbox
# http://www.w3.org/ns/solid/terms#oidcIssuer
# http://xmlns.com/foaf/0.1/img
# http://www.w3.org/2000/10/swap/pim/contact#homePage
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/givenname
# http://xmlns.com/foaf/0.1/based_near
# http://xmlns.com/foaf/0.1/weblog
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://www.w3.org/2006/vcard/ns#fn
# http://xmlns.com/foaf/0.1/homepage
# http://xmlns.com/foaf/0.1/openid
# http://www.w3.org/ns/auth/cert#modulus
# http://www.w3.org/2000/10/swap/pim/contact#postalCode
# http://xmlns.com/foaf/0.1/family_name
# http://xmlns.com/foaf/0.1/nick
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://purl.org/dc/elements/1.1/title

# %%
# Printing subjects, predicates and objects out of the tuple omits Python datatypes
print("--- printing raw triples ---")
for s, p, o in g:
    print(s, p, o)
# Out:
# --- printing raw triples ---
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/nick TimBL
# http://www.w3.org/DesignIssues/Overview.html http://purl.org/dc/elements/1.1/title Design Issues for the World Wide Web
# N0a65e5e17a4a4d60802c311d46d066af http://www.w3.org/2006/vcard/ns#region MA
# N737bbabff0e54ce9b0b5becd6adfebb6 http://www.w3.org/2003/01/geo/wgs84_pos#lat 42.361860
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#preferredURI https://www.w3.org/People/Berners-Lee/card#i
# N1912af6a0f4a4e96b76ac93ef02121e6 http://www.w3.org/ns/auth/cert#exponent 65537
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://www.reddit.com/user/timbl/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#profileBackgroundColor #ffffff
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#editableProfile https://timbl.com/timbl/Public/friends.ttl
# N0a65e5e17a4a4d60802c311d46d066af http://www.w3.org/2006/vcard/ns#postal-code 02139
# http://www.w3.org/data#W3C http://xmlns.com/foaf/0.1/member https://www.w3.org/People/Berners-Lee/card#i
# N1d69280ae86649c89fb536889eb30b73 http://www.w3.org/2000/10/swap/pim/contact#street 32 Vassar Street
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# N0a65e5e17a4a4d60802c311d46d066af http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2006/vcard/ns#Work
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01 http://www.w3.org/2000/01/rdf-schema#label The Next Wave of the Web (Plenary Panel)
# http://www.w3.org/People/Berners-Lee/card http://xmlns.com/foaf/0.1/primaryTopic https://www.w3.org/People/Berners-Lee/card#i
# N737bbabff0e54ce9b0b5becd6adfebb6 http://www.w3.org/2003/01/geo/wgs84_pos#long -71.091840
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk http://purl.org/dc/terms/title Designing the Web for an Open Society
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/01/rdf-schema#label Tim Berners-Lee
# http://www.w3.org/People/Berners-Lee/card http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card http://purl.org/dc/elements/1.1/title Tim Berners-Lee's FOAF file
# https://timbl.com/timbl/Public/friends.ttl http://creativecommons.org/ns#license http://creativecommons.org/licenses/by-nc/3.0/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.com/timbl/Public/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://en.wikipedia.org/wiki/User:Timbl
# http://wiki.ontoworld.org/index.php/_IRW2006 http://purl.org/dc/elements/1.1/title Identity, Reference and the Web workshop 2006
# N1d69280ae86649c89fb536889eb30b73 http://www.w3.org/2000/10/swap/pim/contact#street2 MIT CSAIL Building 32
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.solid.community/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/workplaceHomepage https://www.w3.org/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/name Timothy Berners-Lee
# http://www.w3.org/2000/10/swap/data#Cwm http://usefulinc.com/ns/doap#developer https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#assistant https://www.w3.org/People/Berners-Lee/card#amy
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01 http://www.w3.org/2000/10/swap/pim/contact#participant https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card http://creativecommons.org/ns#license http://creativecommons.org/licenses/by-nc/3.0/
# https://www.w3.org/People/Berners-Lee/card#i http://schema.org/owns https://timblbot.inrupt.net/profile/card#me
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#office Nf0e4c45ef16d4e42a2370f9f71cccf82
# https://timbl.com/timbl/Public/friends.ttl http://xmlns.com/foaf/0.1/primaryTopic https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# N1d69280ae86649c89fb536889eb30b73 http://www.w3.org/2000/10/swap/pim/contact#country USA
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/title Sir
# https://www.w3.org/People/Berners-Lee/card#i http://rdfs.org/sioc/ns#avatar http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg
# N0a65e5e17a4a4d60802c311d46d066af http://www.w3.org/2006/vcard/ns#locality Cambridge
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2006/vcard/ns#hasAddress N0a65e5e17a4a4d60802c311d46d066af
# http://dig.csail.mit.edu/data#DIG http://xmlns.com/foaf/0.1/member https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#publicTypeIndex https://timbl.com/timbl/Public/PublicTypeIndex.ttl
# http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator http://usefulinc.com/ns/doap#developer https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/PersonalProfileDocument
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/10/swap/pim/contact#Male
# Nf0e4c45ef16d4e42a2370f9f71cccf82 http://www.w3.org/2000/10/swap/pim/contact#address N1d69280ae86649c89fb536889eb30b73
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#profileHighlightColor #00467E
# https://timbl.com/timbl/Public/friends.ttl http://purl.org/dc/elements/1.1/title Tim Berners-Lee's editable profile
# https://timbl.com/timbl/Public/friends.ttl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/PersonalProfileDocument
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/Person
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/mbox_sha1sum 965c47c5a70db7407210cef6e4e6f5374a525c5c
# N1912af6a0f4a4e96b76ac93ef02121e6 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/ns/auth/cert#RSAPublicKey
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#publicHomePage http://www.w3.org/People/Berners-Lee/
# N1d69280ae86649c89fb536889eb30b73 http://www.w3.org/2000/10/swap/pim/contact#city Cambridge
# Nf0e4c45ef16d4e42a2370f9f71cccf82 http://www.w3.org/2003/01/geo/wgs84_pos#location N6dd3fcdcad8f449781ac5237aa733b87
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://www.w3.org/2000/01/rdf-schema#seeAlso http://dig.csail.mit.edu/breadcrumbs/blog/feed/4
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.inrupt.net/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://twitter.com/timberners_lee
# N0a65e5e17a4a4d60802c311d46d066af http://www.w3.org/2006/vcard/ns#street-address 32 Vassar Street
# http://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/auth/cert#key N1912af6a0f4a4e96b76ac93ef02121e6
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/01/rdf-schema#seeAlso https://timbl.com/timbl/Public/friends.ttl
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#preferencesFile https://timbl.com/timbl/Data/preferences.n3
# http://www.w3.org/DesignIssues/Overview.html http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/mbox mailto:timbl@w3.org
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/ldp#inbox https://timbl.com/timbl/Public/Inbox
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#oidcIssuer https://timbl.com
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/img https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#homePage http://www.w3.org/People/Berners-Lee/
# N6dd3fcdcad8f449781ac5237aa733b87 http://www.w3.org/2003/01/geo/wgs84_pos#long -71.091840
# http://dig.csail.mit.edu/2007/01/camp/data#course http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/givenname Timothy
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/based_near N737bbabff0e54ce9b0b5becd6adfebb6
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/weblog http://dig.csail.mit.edu/breadcrumbs/blog/4
# N6dd3fcdcad8f449781ac5237aa733b87 http://www.w3.org/2003/01/geo/wgs84_pos#lat 42.361860
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2006/vcard/ns#fn Tim Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/homepage https://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/openid https://www.w3.org/People/Berners-Lee/
# N1912af6a0f4a4e96b76ac93ef02121e6 http://www.w3.org/ns/auth/cert#modulus ...
# N1d69280ae86649c89fb536889eb30b73 http://www.w3.org/2000/10/swap/pim/contact#postalCode 02139
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/family_name Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/nick timbl
# http://wiki.ontoworld.org/index.php/_IRW2006 http://www.w3.org/2000/10/swap/pim/contact#participant https://www.w3.org/People/Berners-Lee/card#i
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://purl.org/dc/elements/1.1/title timbl's blog on DIG

# %%
print("PRINTING SUBJECTS")
for s in g.subjects():
    print(s)
# Out:
# PRINTING SUBJECTS
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/DesignIssues/Overview.html
# N0a65e5e17a4a4d60802c311d46d066af
# N737bbabff0e54ce9b0b5becd6adfebb6
# https://www.w3.org/People/Berners-Lee/card#i
# N1912af6a0f4a4e96b76ac93ef02121e6
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N0a65e5e17a4a4d60802c311d46d066af
# http://www.w3.org/data#W3C
# N1d69280ae86649c89fb536889eb30b73
# http://dig.csail.mit.edu/breadcrumbs/blog/4
# N0a65e5e17a4a4d60802c311d46d066af
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01
# http://www.w3.org/People/Berners-Lee/card
# N737bbabff0e54ce9b0b5becd6adfebb6
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card
# http://www.w3.org/People/Berners-Lee/card
# https://timbl.com/timbl/Public/friends.ttl
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://wiki.ontoworld.org/index.php/_IRW2006
# N1d69280ae86649c89fb536889eb30b73
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/2000/10/swap/data#Cwm
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01
# http://www.w3.org/People/Berners-Lee/card
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl
# https://timbl.com/timbl/Public/friends.ttl
# N1d69280ae86649c89fb536889eb30b73
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N0a65e5e17a4a4d60802c311d46d066af
# https://www.w3.org/People/Berners-Lee/card#i
# http://dig.csail.mit.edu/data#DIG
# https://www.w3.org/People/Berners-Lee/card#i
# http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator
# http://www.w3.org/People/Berners-Lee/card
# https://www.w3.org/People/Berners-Lee/card#i
# Nf0e4c45ef16d4e42a2370f9f71cccf82
# https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl
# https://timbl.com/timbl/Public/friends.ttl
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N1912af6a0f4a4e96b76ac93ef02121e6
# https://www.w3.org/People/Berners-Lee/card#i
# N1d69280ae86649c89fb536889eb30b73
# Nf0e4c45ef16d4e42a2370f9f71cccf82
# http://dig.csail.mit.edu/breadcrumbs/blog/4
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N0a65e5e17a4a4d60802c311d46d066af
# http://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/DesignIssues/Overview.html
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N6dd3fcdcad8f449781ac5237aa733b87
# http://dig.csail.mit.edu/2007/01/camp/data#course
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N6dd3fcdcad8f449781ac5237aa733b87
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# N1912af6a0f4a4e96b76ac93ef02121e6
# N1d69280ae86649c89fb536889eb30b73
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# http://wiki.ontoworld.org/index.php/_IRW2006
# http://dig.csail.mit.edu/breadcrumbs/blog/4

# %%
print("PRINTING PREDICATES")
for p in g.predicates():
    if len(p) > 13:
        print(p)
# Out:
# PRINTING PREDICATES
# http://xmlns.com/foaf/0.1/nick
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2006/vcard/ns#region
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://www.w3.org/2000/10/swap/pim/contact#preferredURI
# http://www.w3.org/ns/auth/cert#exponent
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/ns/solid/terms#profileBackgroundColor
# http://www.w3.org/ns/solid/terms#editableProfile
# http://www.w3.org/2006/vcard/ns#postal-code
# http://xmlns.com/foaf/0.1/member
# http://www.w3.org/2000/10/swap/pim/contact#street
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label
# http://xmlns.com/foaf/0.1/primaryTopic
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://purl.org/dc/terms/title
# http://www.w3.org/2000/01/rdf-schema#label
# http://xmlns.com/foaf/0.1/maker
# http://purl.org/dc/elements/1.1/title
# http://creativecommons.org/ns#license
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/account
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/2000/10/swap/pim/contact#street2
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/workplaceHomepage
# http://xmlns.com/foaf/0.1/name
# http://usefulinc.com/ns/doap#developer
# http://www.w3.org/2000/10/swap/pim/contact#assistant
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://creativecommons.org/ns#license
# http://schema.org/owns
# http://www.w3.org/2000/10/swap/pim/contact#office
# http://xmlns.com/foaf/0.1/primaryTopic
# http://xmlns.com/foaf/0.1/maker
# http://www.w3.org/2000/10/swap/pim/contact#country
# http://xmlns.com/foaf/0.1/title
# http://rdfs.org/sioc/ns#avatar
# http://www.w3.org/2006/vcard/ns#locality
# http://www.w3.org/2006/vcard/ns#hasAddress
# http://xmlns.com/foaf/0.1/member
# http://www.w3.org/ns/solid/terms#publicTypeIndex
# http://usefulinc.com/ns/doap#developer
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/10/swap/pim/contact#address
# http://www.w3.org/ns/solid/terms#profileHighlightColor
# http://purl.org/dc/elements/1.1/title
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://xmlns.com/foaf/0.1/mbox_sha1sum
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/10/swap/pim/contact#publicHomePage
# http://www.w3.org/2000/10/swap/pim/contact#city
# http://www.w3.org/2003/01/geo/wgs84_pos#location
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/ns/pim/space#storage
# http://xmlns.com/foaf/0.1/account
# http://www.w3.org/2006/vcard/ns#street-address
# http://www.w3.org/ns/auth/cert#key
# http://www.w3.org/2000/01/rdf-schema#seeAlso
# http://www.w3.org/ns/pim/space#preferencesFile
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/mbox
# http://www.w3.org/ns/ldp#inbox
# http://www.w3.org/ns/solid/terms#oidcIssuer
# http://xmlns.com/foaf/0.1/img
# http://www.w3.org/2000/10/swap/pim/contact#homePage
# http://www.w3.org/2003/01/geo/wgs84_pos#long
# http://xmlns.com/foaf/0.1/maker
# http://xmlns.com/foaf/0.1/givenname
# http://xmlns.com/foaf/0.1/based_near
# http://xmlns.com/foaf/0.1/weblog
# http://www.w3.org/2003/01/geo/wgs84_pos#lat
# http://www.w3.org/2006/vcard/ns#fn
# http://xmlns.com/foaf/0.1/homepage
# http://xmlns.com/foaf/0.1/openid
# http://www.w3.org/ns/auth/cert#modulus
# http://www.w3.org/2000/10/swap/pim/contact#postalCode
# http://xmlns.com/foaf/0.1/family_name
# http://xmlns.com/foaf/0.1/nick
# http://www.w3.org/2000/10/swap/pim/contact#participant
# http://purl.org/dc/elements/1.1/title

# %%
print("PRINTING OBJECTS")
for o in g.objects():
    print(o)
# Out:
# PRINTING OBJECTS
# TimBL
# Design Issues for the World Wide Web
# MA
# 42.361860
# https://www.w3.org/People/Berners-Lee/card#i
# 65537
# http://www.reddit.com/user/timbl/
# #ffffff
# https://timbl.com/timbl/Public/friends.ttl
# 02139
# https://www.w3.org/People/Berners-Lee/card#i
# 32 Vassar Street
# https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/2006/vcard/ns#Work
# The Next Wave of the Web (Plenary Panel)
# https://www.w3.org/People/Berners-Lee/card#i
# -71.091840
# Designing the Web for an Open Society
# Tim Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i
# Tim Berners-Lee's FOAF file
# http://creativecommons.org/licenses/by-nc/3.0/
# https://timbl.com/timbl/Public/
# http://en.wikipedia.org/wiki/User:Timbl
# Identity, Reference and the Web workshop 2006
# MIT CSAIL Building 32
# https://timbl.solid.community/
# https://www.w3.org/
# Timothy Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#amy
# https://www.w3.org/People/Berners-Lee/card#i
# http://creativecommons.org/licenses/by-nc/3.0/
# https://timblbot.inrupt.net/profile/card#me
# Nf0e4c45ef16d4e42a2370f9f71cccf82
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# USA
# Sir
# http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg
# Cambridge
# N0a65e5e17a4a4d60802c311d46d066af
# https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/PublicTypeIndex.ttl
# https://www.w3.org/People/Berners-Lee/card#i
# http://xmlns.com/foaf/0.1/PersonalProfileDocument
# http://www.w3.org/2000/10/swap/pim/contact#Male
# N1d69280ae86649c89fb536889eb30b73
# #00467E
# Tim Berners-Lee's editable profile
# http://xmlns.com/foaf/0.1/PersonalProfileDocument
# http://xmlns.com/foaf/0.1/Person
# 965c47c5a70db7407210cef6e4e6f5374a525c5c
# http://www.w3.org/ns/auth/cert#RSAPublicKey
# http://www.w3.org/People/Berners-Lee/
# Cambridge
# N6dd3fcdcad8f449781ac5237aa733b87
# http://dig.csail.mit.edu/breadcrumbs/blog/feed/4
# https://timbl.inrupt.net/
# http://twitter.com/timberners_lee
# 32 Vassar Street
# N1912af6a0f4a4e96b76ac93ef02121e6
# https://timbl.com/timbl/Public/friends.ttl
# https://timbl.com/timbl/Data/preferences.n3
# https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i
# mailto:timbl@w3.org
# https://timbl.com/timbl/Public/Inbox
# https://timbl.com
# https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg
# http://www.w3.org/People/Berners-Lee/
# -71.091840
# https://www.w3.org/People/Berners-Lee/card#i
# Timothy
# N737bbabff0e54ce9b0b5becd6adfebb6
# http://dig.csail.mit.edu/breadcrumbs/blog/4
# 42.361860
# Tim Berners-Lee
# https://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/
# ...
# 02139
# Berners-Lee
# timbl
# https://www.w3.org/People/Berners-Lee/card#i
# timbl's blog on DIG

# %% [markdown]
# We can also filter the subjects, predicates and objects we want to retrieve, and match their values like in a database "join" operation

# %%
g = Graph()

# Create an identifier to use as the subject for Donna.
donna = URIRef('urn:donna')
ila = URIRef('urn:ila')
# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (ila, RDF.type, FOAF.Person) )
g.add( (ila, RDF.type, FOAF.Teacher) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )
g.add( (ila, FOAF.mbox, URIRef("mailto:ila@example.org")) )

# For each foaf:Person in the store print out its mbox property.
# print("--- printing mboxes ---")
# for person in g.subjects(RDF.type, FOAF.Person):
#     for mbox in g.objects(person, FOAF.mbox):
#         print(mbox)

# You can reuse matches of subjects to filter further e.g. objects
for entity in g.subjects(RDF.type, None):
    print(entity)
    for objects in g.objects(entity, RDF.type):
        print(objects)
# Out:
# urn:ila
# http://xmlns.com/foaf/0.1/Teacher
# http://xmlns.com/foaf/0.1/Person
# urn:ila
# http://xmlns.com/foaf/0.1/Teacher
# http://xmlns.com/foaf/0.1/Person
# urn:donna
# http://xmlns.com/foaf/0.1/Person

# %% [markdown]
# ### Basic triple matching (almost querying!)
#
# We use method Graph.triples and a Python tuple that acts as a mask for specifying our criteria

# %%
g = Graph()
g.parse("http://www.w3.org/People/Berners-Lee/card")

tim = URIRef("https://www.w3.org/People/Berners-Lee/card#i")

if ( tim, RDF.type, FOAF.Person ) in g:
   print("This graph knows that Tim is a person!")

if ( tim, None, None ) in g:
    print("This graph contains triples about Tim!")
# Out:
# This graph knows that Tim is a person!
# This graph contains triples about Tim!

# %%
for s,p,o in g.triples( (None, None, None) ):
    print(s,p,o)
# Out:
# N3ff07323bac645a6871eedd290d5b770 http://www.w3.org/2000/10/swap/pim/contact#postalCode 02139
# http://dig.csail.mit.edu/data#DIG http://xmlns.com/foaf/0.1/member https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#publicHomePage http://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/Person
# https://timbl.com/timbl/Public/friends.ttl http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/PersonalProfileDocument
# N3ff07323bac645a6871eedd290d5b770 http://www.w3.org/2000/10/swap/pim/contact#street2 MIT CSAIL Building 32
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#profileHighlightColor #00467E
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#preferredURI https://www.w3.org/People/Berners-Lee/card#i
# Nf963e132ac39416ea77fb587f76461d8 http://www.w3.org/2003/01/geo/wgs84_pos#long -71.091840
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/family_name Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/img https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#assistant https://www.w3.org/People/Berners-Lee/card#amy
# http://dig.csail.mit.edu/2007/01/camp/data#course http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/data#W3C http://xmlns.com/foaf/0.1/member https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl http://xmlns.com/foaf/0.1/primaryTopic https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/People/Berners-Lee/card http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/PersonalProfileDocument
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/nick timbl
# http://www.w3.org/People/Berners-Lee/card http://creativecommons.org/ns#license http://creativecommons.org/licenses/by-nc/3.0/
# http://www.w3.org/People/Berners-Lee/card http://purl.org/dc/elements/1.1/title Tim Berners-Lee's FOAF file
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://www.w3.org/2000/01/rdf-schema#seeAlso http://dig.csail.mit.edu/breadcrumbs/blog/feed/4
# https://www.w3.org/People/Berners-Lee/card#i http://schema.org/owns https://timblbot.inrupt.net/profile/card#me
# http://www.w3.org/DesignIssues/Overview.html http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/10/swap/pim/contact#Male
# Nf495450b90ee46b796c52035ac853607 http://www.w3.org/2003/01/geo/wgs84_pos#location N0a78b51bf87a4473815f5a71803f6ddc
# Nf963e132ac39416ea77fb587f76461d8 http://www.w3.org/2003/01/geo/wgs84_pos#lat 42.361860
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk http://purl.org/dc/terms/title Designing the Web for an Open Society
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/homepage https://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://rdfs.org/sioc/ns#avatar http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#editableProfile https://timbl.com/timbl/Public/friends.ttl
# N3ff07323bac645a6871eedd290d5b770 http://www.w3.org/2000/10/swap/pim/contact#country USA
# N0a78b51bf87a4473815f5a71803f6ddc http://www.w3.org/2003/01/geo/wgs84_pos#lat 42.361860
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/workplaceHomepage https://www.w3.org/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#profileBackgroundColor #ffffff
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/ldp#inbox https://timbl.com/timbl/Public/Inbox
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/title Sir
# http://wiki.ontoworld.org/index.php/_IRW2006 http://www.w3.org/2000/10/swap/pim/contact#participant https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://twitter.com/timberners_lee
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/openid https://www.w3.org/People/Berners-Lee/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2006/vcard/ns#hasAddress N0d0a67cfab294ce38a1b6e7399b0ab3d
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://purl.org/dc/elements/1.1/title timbl's blog on DIG
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/weblog http://dig.csail.mit.edu/breadcrumbs/blog/4
# N0d0a67cfab294ce38a1b6e7399b0ab3d http://www.w3.org/2006/vcard/ns#region MA
# http://wiki.ontoworld.org/index.php/_IRW2006 http://purl.org/dc/elements/1.1/title Identity, Reference and the Web workshop 2006
# N0a78b51bf87a4473815f5a71803f6ddc http://www.w3.org/2003/01/geo/wgs84_pos#long -71.091840
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://en.wikipedia.org/wiki/User:Timbl
# N94c3fdb7c0d041c28355832ab811c5e8 http://www.w3.org/ns/auth/cert#modulus ...
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01 http://www.w3.org/2000/01/rdf-schema#label The Next Wave of the Web (Plenary Panel)
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/account http://www.reddit.com/user/timbl/
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#office Nf495450b90ee46b796c52035ac853607
# https://timbl.com/timbl/Public/friends.ttl http://purl.org/dc/elements/1.1/title Tim Berners-Lee's editable profile
# N3ff07323bac645a6871eedd290d5b770 http://www.w3.org/2000/10/swap/pim/contact#street 32 Vassar Street
# http://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/auth/cert#key N94c3fdb7c0d041c28355832ab811c5e8
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/01/rdf-schema#seeAlso https://timbl.com/timbl/Public/friends.ttl
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/name Timothy Berners-Lee
# http://www.w3.org/People/Berners-Lee/card http://xmlns.com/foaf/0.1/primaryTopic https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#preferencesFile https://timbl.com/timbl/Data/preferences.n3
# http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# N3ff07323bac645a6871eedd290d5b770 http://www.w3.org/2000/10/swap/pim/contact#city Cambridge
# N0d0a67cfab294ce38a1b6e7399b0ab3d http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2006/vcard/ns#Work
# N94c3fdb7c0d041c28355832ab811c5e8 http://www.w3.org/ns/auth/cert#exponent 65537
# N0d0a67cfab294ce38a1b6e7399b0ab3d http://www.w3.org/2006/vcard/ns#street-address 32 Vassar Street
# http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator http://usefulinc.com/ns/doap#developer https://www.w3.org/People/Berners-Lee/card#i
# http://www.w3.org/DesignIssues/Overview.html http://purl.org/dc/elements/1.1/title Design Issues for the World Wide Web
# http://www.w3.org/2000/10/swap/data#Cwm http://usefulinc.com/ns/doap#developer https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/01/rdf-schema#label Tim Berners-Lee
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/mbox mailto:timbl@w3.org
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#publicTypeIndex https://timbl.com/timbl/Public/PublicTypeIndex.ttl
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2000/10/swap/pim/contact#homePage http://www.w3.org/People/Berners-Lee/
# N0d0a67cfab294ce38a1b6e7399b0ab3d http://www.w3.org/2006/vcard/ns#postal-code 02139
# N0d0a67cfab294ce38a1b6e7399b0ab3d http://www.w3.org/2006/vcard/ns#locality Cambridge
# http://www.w3.org/People/Berners-Lee/card http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://timbl.com/timbl/Public/friends.ttl http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.solid.community/
# https://timbl.com/timbl/Public/friends.ttl http://creativecommons.org/ns#license http://creativecommons.org/licenses/by-nc/3.0/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/based_near Nf963e132ac39416ea77fb587f76461d8
# Nf495450b90ee46b796c52035ac853607 http://www.w3.org/2000/10/swap/pim/contact#address N3ff07323bac645a6871eedd290d5b770
# http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01 http://www.w3.org/2000/10/swap/pim/contact#participant https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.inrupt.net/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/nick TimBL
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/mbox_sha1sum 965c47c5a70db7407210cef6e4e6f5374a525c5c
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/pim/space#storage https://timbl.com/timbl/Public/
# https://www.w3.org/People/Berners-Lee/card#i http://xmlns.com/foaf/0.1/givenname Timothy
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/2006/vcard/ns#fn Tim Berners-Lee
# N94c3fdb7c0d041c28355832ab811c5e8 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/ns/auth/cert#RSAPublicKey
# http://dig.csail.mit.edu/breadcrumbs/blog/4 http://xmlns.com/foaf/0.1/maker https://www.w3.org/People/Berners-Lee/card#i
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/ns/solid/terms#oidcIssuer https://timbl.com

# %%
for s,p,o in g.triples( (tim, RDF.type, None) ):
    print(s,p,o)
# Out:
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/10/swap/pim/contact#Male
# https://www.w3.org/People/Berners-Lee/card#i http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://xmlns.com/foaf/0.1/Person

# %% [markdown]
# ## Namespaces and bindings

# %%
mid_uri = URIRef("http://purl.org/midi-ld/midi#")
mid = Namespace(mid_uri)

print(mid['hello'])  # as item - for things that are not valid python identifiers
print(mid.hello)     # as attribute
# Out:
# http://purl.org/midi-ld/midi#hello
# http://purl.org/midi-ld/midi#hello

# %%
g = Graph()

# Create an identifier to use as the subject for Donna.
donna = BNode()

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

print(g.serialize(format='turtle').decode())
# Out:
# @prefix ns1: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# [] a ns1:Person ;
#     ns1:mbox <mailto:donna@example.org> ;
#     ns1:name "Donna Fales" ;
#     ns1:nick "donna"@foo .

# %%
foaf_uri = URIRef("http://xmlns.com/foaf/0.1/")
foaf_namespace = Namespace(foaf_uri)

g = Graph()

# Bind a few prefix, namespace pairs for more readable output
g.bind("foaf", foaf_namespace)

# Create an identifier to use as the subject for Donna.
donna = BNode()

# Add triples using store's add method.
g.add( (donna, RDF.type, FOAF.Person) )
g.add( (donna, FOAF.nick, Literal("donna", lang="foo")) )
g.add( (donna, FOAF.name, Literal("Donna Fales")) )
g.add( (donna, FOAF.mbox, URIRef("mailto:donna@example.org")) )

print(g.serialize(format='turtle').decode())
# Out:
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# [] a foaf:Person ;
#     foaf:mbox <mailto:donna@example.org> ;
#     foaf:name "Donna Fales" ;
#     foaf:nick "donna"@foo .
