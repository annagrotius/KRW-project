# %%
import glob
from rdflib import Graph

# %%
mesh_g = Graph()

for file in glob.glob('./mesh_queries/*.ttl'):
    mesh_g.parse(file, format='turtle')
print(len(mesh_g))
# Out:
# 12945

# %%
mesh_g.serialize('mesh_graph.ttl', format='turtle')
