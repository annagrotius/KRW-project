# %%
import pandas as pd
#from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt

# %%
# run this block to install wordcloud
# pip instalL wordcloud

# %%
data = pd.read_csv('abstract_data.csv')
keywords = data.keywords

# %%
clean_items = []
for i in keywords:
    i = i.replace('[', '')   
    i = i.replace(']', '')  
    clean_items.append(i)
    
data.keywords = clean_items

# %%
def clean_text(series):
    clean_words = []
    list_of_words = series.split(',')
    for word in list_of_words:
#word = word.replace('_', ' ')      
        word = word.replace("'", '')
        word = word.lower()
        word = word.strip(' ')
        clean_words.append(word)
    return clean_words

# %%
data.keywords = data.keywords.apply(clean_text)

# %%
# Keywords = the noun entities taken from the merged noun_chunks
# Here we clean them and then tokenize them

def clean_keyword(text):
    cleaned_keywords = []
    for word in (text):
        word.split(' ')
        new_word = word.replace('_', ' ')
        cleaned_keywords.append(new_word)
    
    return cleaned_keywords

def tokenize(text):
    res = [sub.split() for sub in text]
    flattened = [i for j in res for i in j]
    return flattened

# %%
data['keywords_clean'] = data["keywords"].astype(str)
# clean the keywords
data['keywords_clean'] = data['keywords'].apply(clean_keyword)
# tokenize 
data['tokens'] = data['keywords_clean'].apply(tokenize)
# put tokens into set
data['tuple_tokens'] = data['tokens'].apply(set)

# %%
# We start with keywords - which are nouns that were extracted from noun-chunks

for row in data.keywords[0:5]:  # iterating through the rows of the object column
    print(row, '\n')

# %%
# We then tokenize those keywords

for row in data.tokens[0:5]:  # iterating through the rows of the object column
    print(row, '\n')
# Out:
# ['a', 'liposome-based', 'anti-cancer', 'vaccine']
#
# ['a', 'scoping', 'review', 'the', 'literature', 'nurses’', 'dual', 'practice', 'the', 'objective', 'generating', 'hypotheses', 'its', 'nature', 'consequences', 'a', 'research', 'agenda', 'the', 'phenomenon']
#
# ['the', 'expression', 'sialic', 'acid', 'o-acetylesterases', 'a', 'broad', 'specificity', 'competition', 'the', 'gut', 'microbiota', 'nutrients', 'ehec', 'colonization', 'the', 'human', 'large', 'intestine']
#
# ['ra', 'dcs', 'an', 'immature', 'mucosal', 'phenotype', 'the', 'small', 'intestinal', 'submucosa']
#
# ['fiv', 'infection', 'dysregulation', 'trophoblast', 'immunomodulator', 'expression', 'aberrant', 'expression', 'these', 'molecules', 'inflammation', 'compromise', 'pregnancy']

# %%
# These are all the functions that are run on the tokens sets to clean up the tokens column

def drop_double_char(ents):
    """Drop any entities that are less than three characters. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    drop_ents = {ent for ent in ents if len(ent) < 3}
    return ents - drop_ents

def keep_alpha(ents):
    """Keep only entities with alphabetical unicode characters, hyphens, and spaces. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    keep_char = set('-abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ ')
    drop_ents = {ent for ent in ents if not set(ent).issubset(keep_char)}
    return ents - drop_ents

def drop_single_char_nps(ents):
    """Within an entity, drop single characters. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    return {' '.join([e for e in ent.split(' ') if not len(e) == 1]) for ent in ents}

def remove_freq_words(entities):
    """Drop any entities in the 5000 most common words in the English langauge. 
    
    Keyword arguments:
    ents -- a set of entities
    
    """
    freq_words = pd.read_csv('datasets_freq_words.csv')['Word'].iloc[1:]
    for word in freq_words:
        try:
            entities.remove(word)
        except KeyError:
            continue # ignore the stop word if it's not in the list of abstract entities
    return entities

def add_clean_ents(df, funcs=[]):
    """Create new column in data frame with cleaned entities.
    
    Keyword arguments:
    df -- a dataframe object
    funcs -- a list of heuristic functions to be applied to entities
    
    """
    col = 'tuple_tokens_clean'
    df[col] = df['tuple_tokens']
    for f in funcs:
        df[col] = df[col].apply(f)

# %%
# We run all the functions through 'add clean ents function'

functions = [drop_double_char, keep_alpha, drop_single_char_nps, remove_freq_words]
add_clean_ents(data, functions)

# %%
# Taking a look at the cleaned tokens

for row in data.tuple_tokens_clean[0:5]:  # iterating through the rows of the object column
    print(row, '\n')
# Out:
# {'liposome-based', 'anti-cancer', 'vaccine'}
#
# {'scoping', 'consequences', 'generating', 'dual'}
#
# {'ehec', 'sialic', 'o-acetylesterases', 'specificity', 'microbiota', 'nutrients', 'intestine', 'colonization'}
#
# {'dcs', 'mucosal', 'phenotype', 'submucosa', 'immature', 'intestinal'}
#
# {'fiv', 'aberrant', 'trophoblast', 'dysregulation', 'immunomodulator', 'inflammation', 'molecules'}

# %%
# Put the set of sets into a list, expand the list and create one final clean set

def large_list(text):
    large_list = []
    for word in (text):
        word.split(',')
        if word not in large_list:
            large_list.append(word)
    return large_list

data["list_clean"] = data["tuple_tokens_clean"].apply(large_list)
aggregated_list = data.list_clean.sum()

unique_tokens = set()
for word in aggregated_list:
    unique_tokens.add(word)

# %%
# This is the flattened set that we use to create the SPARQL query

unique_tokens
# Out:
# {'hitherto',
#  'tiv',
#  'neurodegeneration',
#  'vaccinated',
#  'tests',
#  'catechin',
#  'psycho-neuroendocrinological',
#  'explanatory',
#  'sct',
#  'acquired',
#  'lrti',
#  'european',
#  'controlled',
#  'adjacent',
#  'rejection',
#  'cia',
#  'fragmentation',
#  'fluorescence',
#  'prrsv',
#  'ichnovirus',
#  'huanan',
#  'vascular',
#  'adipogenesis',
#  'diarrhea',
#  'cytokine',
#  'sars',
#  'validation',
#  'spatial',
#  'attenuated',
#  'bstvs',
#  'ndv',
#  'viable',
#  'implications',
#  'camels',
#  'pcr-reactions',
#  'heparan',
#  'node',
#  'ifitms',
#  'isothermal',
#  'rbct',
#  'lining',
#  'sporadic',
#  'risks',
#  'rabv',
#  'permeability',
#  'insults',
#  'bocv',
#  'methods',
#  'aetiology',
#  'singapore',
#  'vuvuzelas',
#  'ones',
#  'residues',
#  'parts',
#  'placental',
#  'subjective',
#  'voles',
#  'insights',
#  'african',
#  'gof',
#  'spinal',
#  'antigens',
#  'causal',
#  'astv',
#  'large-del',
#  'bovine',
#  'evt',
#  'spherules',
#  'covmpro',
#  'thymocyte',
#  'lcmv',
#  'dehydration',
#  'antibody',
#  'chb',
#  'hundreds',
#  'orthomyxovirus',
#  'horses',
#  'drug',
#  'proteases',
#  'camel',
#  'cancers',
#  'crp',
#  'discussions',
#  'causes',
#  'conflicting',
#  'diagnostic',
#  'conceptual',
#  'mycoplasma',
#  'ifn',
#  'influences',
#  'sorting',
#  'deubiquitinating',
#  'treg',
#  'synergistic',
#  'dimorphic',
#  'co-evolution',
#  'asymptomatic',
#  'oligodendrocytes',
#  'downregulation',
#  'taxonomy',
#  'lymphocytes',
#  'countries',
#  'causality',
#  'morphotype',
#  'kawasaki',
#  'real-time',
#  'untranslated',
#  'follow-up',
#  'origins',
#  'proteome',
#  'analytic',
#  'regression',
#  'microglial',
#  'imperfections',
#  'fibrinolysis',
#  'frameworks',
#  'cxr',
#  'ingestive',
#  'volumes',
#  'collectrin',
#  'breadth',
#  'outbreaks',
#  'rigorous',
#  'ptm',
#  'necrosis',
#  'superantigen',
#  'maturation',
#  'documented',
#  'broader',
#  'co-infection',
#  'lactate',
#  'blood-based',
#  'tace',
#  'accumulation',
#  'gammacoronaviruses',
#  'rabies',
#  'breaths',
#  'trends',
#  'filariasis',
#  'pseudoknot',
#  'activities',
#  'epidermal',
#  'resistant',
#  'recombinant',
#  'trials',
#  'zuk',
#  'hcmv',
#  'tools',
#  'genotype',
#  'quarantine',
#  'antimalarial',
#  'zikv',
#  'interruption',
#  'assumptions',
#  'sets',
#  'pharmacology',
#  'onfh',
#  'ancestors',
#  'ternary',
#  'populations',
#  'periodontal',
#  'advantages',
#  'deletions',
#  'propagation',
#  'stimulatory',
#  'optimism',
#  'ari',
#  'scientists',
#  'tyrosine',
#  'bcov',
#  'confirmation',
#  'olfactory',
#  'enterocytes',
#  'vesicles',
#  'flaviviridae',
#  'dmog',
#  'signaling',
#  'confirming',
#  'lethal',
#  'americans',
#  'gibbons',
#  'genomes',
#  'phosphatidylethanolamine',
#  'tested',
#  'phenotypes',
#  'progression',
#  'cytotoxicity',
#  'basigin',
#  'vivo',
#  'nsaids',
#  'colleagues',
#  'opposing',
#  'corticosteroid',
#  'mammary',
#  'low-fidelity',
#  'genome',
#  'restrictions',
#  'fipv',
#  'intrahost',
#  'outbreak',
#  'inactivated',
#  'zoo',
#  'circulating',
#  'materials',
#  'beneficial',
#  'professionals',
#  'absent',
#  'aom',
#  'epidemiology',
#  'pneumoniae',
#  'trophoblast',
#  'june',
#  'transgene',
#  'marrow',
#  'thymic',
#  'immunological',
#  'meteorological',
#  'proteosome-sensitive',
#  'fecv',
#  'nss',
#  'pharmaceuticals',
#  'rna',
#  'suilysin',
#  'amplification',
#  'plpro',
#  'neurona',
#  'transient',
#  'religiosity',
#  'capabilities',
#  'mature',
#  'sarsr-covs',
#  'empyema',
#  'genomic',
#  'rnai-like',
#  'protracted',
#  'turnover',
#  'mirna',
#  'dehydrogenase',
#  'machinery',
#  'proteins',
#  'evidences',
#  'bronchiolitis',
#  'earliest',
#  'occurrence',
#  'manifestation',
#  'weeks',
#  'antitumor',
#  'systematic',
#  'mammals',
#  'antiretroviral',
#  'intravenous',
#  'mediator',
#  'apoptotic',
#  'badgers',
#  'discovered',
#  'docking',
#  'prematurity',
#  'tcr',
#  'pathogen',
#  'ehec',
#  'lps',
#  'lineages',
#  'subtypes',
#  'vero',
#  'heterogeneity',
#  'inhibits',
#  'timeframes',
#  'rtis',
#  'immunomodulatory',
#  'oscillation',
#  'virus-host',
#  'inability',
#  'versions',
#  'community-acquired',
#  'sloppiness',
#  'mating',
#  'decoy',
#  'mimicry',
#  'pathophysiology',
#  'yagouaroundi',
#  'tmev',
#  'interferons',
#  'felv',
#  'cases',
#  'efforts',
#  'variants',
#  'biosafety',
#  'o-acetylesterases',
#  'restricted',
#  'exacerbations',
#  'immunization',
#  'viruses',
#  'coated',
#  'non-lethal',
#  'mutations',
#  'quercetin',
#  'probit',
#  'tryptophan',
#  'clad',
#  'metastasis',
#  'surrogate',
#  'assay',
#  'continental',
#  'evolutionary-based',
#  'leptospira-induced',
#  'vzv',
#  'retinopathy',
#  'cell-mediated',
#  'indirect',
#  'constraints',
#  'fip',
#  'multigroup',
#  'uganda',
#  'viral-bacterial',
#  'hematopoietic',
#  'collaborators',
#  'mrna',
#  'serum',
#  'preludes',
#  'enzymes',
#  'coronaviruses',
#  'nonstructural',
#  'lymphocyte',
#  'bronchitis',
#  'disparity',
#  'profiles',
#  'resonance',
#  'gastroenteritis',
#  'inflammation',
#  'plasmacytoid',
#  'conceptualization',
#  'ubiquitous',
#  'receptor-',
#  'glioma',
#  'exacerbation',
#  'abdominal',
#  'thailand',
#  'scales',
#  'tapcs',
#  'dephosphorylation',
#  'lipopolysaccharide',
#  'libraries',
#  'ifng',
#  'antigen',
#  'protease',
#  'iran',
#  'regulators',
#  'bcrp',
#  'contributes',
#  'datasets',
#  'hybridization',
#  'developed',
#  'baseline',
#  'symptoms',
#  'humans',
#  'non-enterotropic',
#  'fragments',
#  'neurologic',
#  'inoculum',
#  'gag',
#  'dividing',
#  'airflow',
#  'bat-maintenance',
#  'zinkernagel',
#  'fcovs',
#  'producers',
#  'syntaxin',
#  'precursors',
#  'template',
#  'dairy',
#  'precipitation',
#  'inhibitory',
#  'crosstalk',
#  'highlights',
#  'positively',
#  'dubs',
#  'subsite',
#  'pneumonia',
#  'infants',
#  'tier',
#  'health-care',
#  'gland',
#  'stem-loop',
#  'dissemination',
#  'diarrhoea',
#  'beliefs',
#  'tissues',
#  'evolutionary',
#  'promiscuous',
#  'diagnostics',
#  'tract',
#  'stochastic',
#  'a-count',
#  'hcvcc',
#  'autism',
#  'regions',
#  'intake',
#  'membrane',
#  'niemann',
#  'microcephaly',
#  'domains',
#  'igs',
#  'cyanocobalamin',
#  'permutation',
#  'fluidity',
#  'pandemic',
#  'myeloid',
#  'indels',
#  'adherence',
#  'high-symptom',
#  'pulmonary',
#  'subset',
#  'igg',
#  'persistence',
#  'suspected',
#  'incidence',
#  'expressions',
#  'conclusions',
#  'shedding',
#  'culture-adapted',
#  'civets',
#  'axis',
#  'vector',
#  'piglets',
#  'agonist',
#  'prevalence',
#  'antioxidant',
#  'cultures',
#  'pbc',
#  'lumen',
#  'hearts',
#  'emphysema',
#  'cardiac',
#  'chondroitin',
#  'foothold',
#  'dampening',
#  'genome-wide',
#  'mbsr',
#  'endemic',
#  'eae',
#  'deficiencies',
#  'findings',
#  'ion',
#  'araneus',
#  'ticks',
#  'anti-cancer',
#  'complementarity',
#  'affymetrix',
#  'mitochondrion',
#  'times',
#  'ngal',
#  'cooling',
#  'proteosome-resistant',
#  'submucosa',
#  'herein',
#  'hypothesized',
#  'antigenic',
#  'onset',
#  'sirna',
#  'rnase',
#  'algorithm',
#  'undergoing',
#  's-adenosylmethionine',
#  'mothers',
#  'nephropathy',
#  'homozygosity',
#  'renin',
#  'stronger',
#  'viraemia',
#  'potent',
#  'complexes',
#  'connective',
#  'mechanistic',
#  'reemerging',
#  'factors',
#  'strategies',
#  'intensive',
#  'antiviral',
#  'carcinogenesis',
#  'therapies',
#  'probiotic',
#  'vnas',
#  'plasma',
#  'biochemical',
#  'chymotrypsin-like',
#  'cross-sectional',
#  'galv',
#  'scrutiny',
#  'ten-year',
#  'stnx',
#  'repercussions',
#  'anionic',
#  'nstvs',
#  'ebv-driven',
#  'multi-factorial',
#  'ascs',
#  'simulation',
#  'handles',
#  'pecorum',
#  'transfection',
#  'epidermis',
#  'innate',
#  'isolates',
#  'torsional',
#  'imports',
#  'infectivity',
#  'gradual',
#  'immature',
#  'shap',
#  'contaminated',
#  'inhaled',
#  'pathology',
#  'modelling',
#  'trachomatis',
#  'observations',
#  'substrate',
#  'cell-receptor',
#  'geographically',
#  'sero-prevalence',
#  'patients',
#  'variations',
#  'heuristic',
#  'salmonella',
#  'institute',
#  'dtu',
#  'curvature',
#  'recurrence',
#  'ntp-dependent',
#  'focused',
#  'cov',
#  'operations',
#  'varying',
#  'descriptive',
#  'multi-disciplinary',
#  'neonatal',
#  'vivo-morpholinos',
#  'segmentation',
#  'mhc',
#  'kinases',
#  'cheetah',
#  'disruption',
#  'azithromycin',
#  'oxide',
#  'anti-cat',
#  'disorders',
#  'smokers',
#  'horizontal',
#  'pathogenesis',
#  'oxidation',
#  'patterns',
#  'complication',
#  'substantive',
#  'fecal',
#  'ghanaian',
#  'catalytic',
#  'unfolding',
#  'comorbidity',
#  'chikv',
#  'deft',
#  'prime-boost',
#  'mtct',
#  'qtl',
#  'ctsl',
#  'allograft',
#  'etiology',
#  'immunoglobulins',
#  'markedly',
#  'invasive',
#  'interviews',
#  'graft',
#  'cyclophilin',
#  'superimposed',
#  'forgo',
#  'tasks',
#  'helix',
#  'unbound',
#  'adaptation',
#  'unrepaired',
#  'matured',
#  'secretory',
#  'snp',
#  'extrinsic',
#  'disturbance',
#  'pedv-induced',
#  'fiv',
#  'zoogeographical',
#  'adaptive',
#  'cytopathic',
#  'geography',
#  'aims',
#  'binding',
#  'herd',
#  'helical',
#  'aibv',
#  'structurally',
#  'cids',
#  'stretches',
#  'aecs',
#  'aceturate',
#  'copies',
#  'post-blood',
#  'catabolism',
#  'diminazene',
#  'ntp-binding',
#  'span',
#  'isavirus',
#  'arthritic',
#  'renin-angiotensin',
#  'transmembrane',
#  'panmictic',
#  'resulting',
#  'hydrophobic',
#  'bundles',
#  'dual',
#  'parvoviruses',
#  'signs',
#  'ppar',
#  'genera',
#  'norovirus',
#  'allostery',
#  'nsg',
#  'platelet',
#  'oasl',
#  'polyvalent',
#  'maternal',
#  'pmps',
#  'hypertension',
#  'nasopharyngeal',
#  'ali',
#  'efficacy',
#  'cellular',
#  'homologous',
#  'poliovirus',
#  'organizations',
#  'australia',
#  'contacts',
#  'bacterial',
#  'intron',
#  'supplementation',
#  'alterations',
#  'bands',
#  'deficiency',
#  'networks',
#  'antagonist',
#  'rats',
#  'yeast',
#  'phosphorylation',
#  'large-scale',
#  'familial',
#  'incoming',
#  'dysbiosis',
#  'exothermic',
#  'knockouts',
#  'sulfation',
#  'environments',
#  'denv',
#  'null',
#  'virulent',
#  'alveolar',
#  'chloroquine',
#  'avian',
#  'single-hit',
#  'respiratory',
#  'obese',
#  'acute',
#  'evasion',
#  'low-symptom',
#  'conclusive',
#  'anti-microbial',
#  'paralogs',
#  'thymocytes',
#  'symptomatic',
#  'collectins',
#  'hong',
#  'miniopterus',
#  'virus-positive',
#  're-infection',
#  'neurological',
#  'vaccination',
#  'bkv',
#  'adrenal',
#  'prolonged',
#  'heater',
#  'neutralizing',
#  'superinfection',
#  'eosinophil',
#  'orderly',
#  'astrovirus',
#  'simulations',
#  'hcov',
#  'cadherin',
#  'trypanosome',
#  'options',
#  'fusion',
#  'densities',
#  'experiments',
#  'viral',
#  'mannan',
#  'rhinoviruses',
#  'cockroach',
#  'kinase',
#  'siv',
#  'cytokinemia',
#  'sporozoites',
#  'recombination',
#  'sub-lineages',
#  'attenuation',
#  'neonate',
#  'mannose',
#  'autoimmunity',
#  'thoracic',
#  'longevity',
#  'tbev',
#  'observed',
#  'calves',
#  'cps-cq',
#  'effector',
#  'markers',
#  'cleavage',
#  'multi-functional',
#  'neurons',
#  'urine',
#  'intestine',
#  'sequences',
#  'suppression',
#  'hrvs',
#  'cathepsin',
#  'changed',
#  'ubiquitin',
#  'reports',
#  'nitric',
#  'frameshift',
#  'functions',
#  'agonists',
#  'declining',
#  'ups',
#  'plausible',
#  'abs',
#  'hela',
#  'interacting',
#  'bundle',
#  'genotypic',
#  'intestinal',
#  'zero-inflated',
#  'sequestered',
#  'ranavirus',
#  'agents',
#  'age-matched',
#  'passive',
#  'anti-prrsv',
#  'fret',
#  'emergence',
#  'lrtis',
#  'immunomodulator',
#  'mitochondrial',
#  'birth-and-death',
#  'core-rna',
#  'fungus',
#  'levels',
#  'lipids',
#  'rates',
#  'microbiota',
#  'cortical',
#  'similarities',
#  'corona-',
#  'desmethylicaritin',
#  'emr-based',
#  'ivig',
#  'well-coordinated',
#  'proximity',
#  'colonized',
#  'dormancy',
#  'individuals',
#  'nec',
#  'membranes',
#  'genotypes',
#  'cvid',
#  'postnatal',
#  'virulence',
#  'infectious',
#  'schizotypal',
#  'roles',
#  'conditions',
#  'hepeviridae',
#  'hypothesis-driven',
#  'recruited',
#  'intermediate',
#  'lavage',
#  'multiplex',
#  'coordinated',
#  'tcov',
#  'jun',
#  'parasite',
#  'mismatch',
#  'arabian',
#  'results',
#  'cerebrospinal',
#  'nucleotide',
#  'probability',
#  'ses',
#  'cert-dependent',
#  'truncation',
#  'tfs',
#  'enhanced',
#  'differences',
#  'fats',
#  'controls',
#  'higher',
#  'ceramide',
#  'provocative',
#  'immunoglobulin',
#  'elastase',
#  'proofreading',
#  'proliferation',
#  'polymorphisms',
#  'variability',
#  'long-lasting',
#  'peptides',
#  'hav',
#  'virions',
#  'synthesis',
#  'highest',
#  'proteomic',
#  'mauritian',
#  'clinically',
#  'monocytes',
#  'gradient',
#  'ribosomal',
#  'strengths',
#  'expressing',
#  'critically',
#  'brd',
#  'forms',
#  'asthma',
#  'amino',
#  'lectin',
#  'teh',
#  'ligands',
#  'endogenous',
#  'titre',
#  'outcomes',
#  'orthogonal',
#  'situ',
#  'enteric',
#  'negligible',
#  'disease',
#  'organisms',
#  'nucleus',
#  'indonesia',
#  'incorporation',
#  'gilts',
#  'seafood',
#  'transmissibility',
#  'electrolytes',
#  'remodeling',
#  'years',
#  'mixing',
#  'activators',
#  'pediatric',
#  'hms',
#  'dams',
#  'korv',
#  'differential',
#  'strains',
#  'maturing',
#  'computation-derived',
#  'replicates',
#  'seroprevalence',
#  'aerosols',
#  'studies',
#  'porv',
#  'pseudoknots',
#  'formulation',
#  'positions',
#  'fcov-infected',
#  'fixation',
#  'microglia',
#  'crosslinkers',
#  'presentations',
#  'ctl',
#  'primate',
#  'usage',
#  'ribavirin',
#  'vigorous',
#  'neuropathogenesis',
#  'pcr',
#  'systemic',
#  'therapeutic',
#  'polycation',
#  'virus-specific',
#  'cleave',
#  'played',
#  'pathogenetic',
#  'events',
#  'ntpase',
#  'silico',
#  'iga',
#  'spillover',
#  'mutation',
#  'isotype-specific',
#  'lds',
#  'pathological',
#  'predisposition',
#  'exogenous',
#  'o-linked',
#  'induces',
#  'trimester',
#  'boar',
#  'optic',
#  'transgenic',
#  'reported',
#  'passively',
#  'climates',
#  'recommendations',
#  'hydrophilic',
#  'homooligomeric',
#  'lactation',
#  'modification',
#  'reasons',
#  'downstream',
#  'hydrophobicity',
#  'neutrophils',
#  'earlier',
#  'scenarios',
#  'fidelity',
#  'differentiation',
#  'convincing',
#  'angiotensin-converting',
#  'rotavirus',
#  'interventions',
#  'defects',
#  'coagulation',
#  'prototype',
#  'membranous',
#  'novirhabdovirus',
#  'distances',
#  'replication',
#  'icam-grabbing',
#  'cut-off',
#  'comparative',
#  'effectors',
#  'zoonotic',
#  'odn',
#  'arbovirus',
#  'sendai',
#  'co-pathogens',
#  'circovirus',
#  'peptide',
#  'felis',
#  'ascoviruses',
#  'sarcoma',
#  'visualization',
#  'doses',
#  'phytoestrogen',
#  'nonlinear',
#  'distributions',
#  'abortus',
#  'structure-based',
#  'microbiome',
#  'circulation',
#  'unifying',
#  'antecedents',
#  'proteome-wide',
#  'dictates',
#  'mosquito',
#  'rodents',
#  'hospitalized',
#  'complementary',
#  'parameters',
#  'abnormalities',
#  'reovirus',
#  'cocktail',
#  'nonfunctional',
#  'cynomolgus',
#  'oligoclonal',
#  'samples',
#  'metacommunity',
#  'rodent',
#  'neuronal',
#  'nucleolus',
#  'c-type',
#  'alpha',
#  'env',
#  'ancestral',
#  'octapeptide',
#  'tgev',
#  'cfp',
#  'impairment',
#  'insufficient',
#  'case-control',
#  'rhinolophidae',
#  'intricate',
#  'rnc',
#  'erythrocyte',
#  'pedv-positive',
#  'sitewise',
#  'repeated',
#  'hfold',
#  'households',
#  'areas',
#  ...}

# %%
def sparql_query(text):

    print ("WHERE {")
    print ("?sub meshv:preferredConcept ?pa .")
    print ("?pa rdfs:label ?paLabel .")
    print ("FILTER(")
    for keyword in text:
        print (f"REGEX(?paLabel, \'^{keyword}', 'i') ||")
    print ("}\n")

# %%
sparql_query(unique_tokens)
# Out:
# WHERE {
# ?sub meshv:preferredConcept ?pa .
# ?pa rdfs:label ?paLabel .
# FILTER(
# REGEX(?paLabel, '^hitherto', 'i') ||
# REGEX(?paLabel, '^tiv', 'i') ||
# REGEX(?paLabel, '^neurodegeneration', 'i') ||
# REGEX(?paLabel, '^vaccinated', 'i') ||
# REGEX(?paLabel, '^tests', 'i') ||
# REGEX(?paLabel, '^catechin', 'i') ||
# REGEX(?paLabel, '^psycho-neuroendocrinological', 'i') ||
# REGEX(?paLabel, '^explanatory', 'i') ||
# REGEX(?paLabel, '^sct', 'i') ||
# REGEX(?paLabel, '^acquired', 'i') ||
# REGEX(?paLabel, '^lrti', 'i') ||
# REGEX(?paLabel, '^european', 'i') ||
# REGEX(?paLabel, '^controlled', 'i') ||
# REGEX(?paLabel, '^adjacent', 'i') ||
# REGEX(?paLabel, '^rejection', 'i') ||
# REGEX(?paLabel, '^cia', 'i') ||
# REGEX(?paLabel, '^fragmentation', 'i') ||
# REGEX(?paLabel, '^fluorescence', 'i') ||
# REGEX(?paLabel, '^prrsv', 'i') ||
# REGEX(?paLabel, '^ichnovirus', 'i') ||
# REGEX(?paLabel, '^huanan', 'i') ||
# REGEX(?paLabel, '^vascular', 'i') ||
# REGEX(?paLabel, '^adipogenesis', 'i') ||
# REGEX(?paLabel, '^diarrhea', 'i') ||
# REGEX(?paLabel, '^cytokine', 'i') ||
# REGEX(?paLabel, '^sars', 'i') ||
# REGEX(?paLabel, '^validation', 'i') ||
# REGEX(?paLabel, '^spatial', 'i') ||
# REGEX(?paLabel, '^attenuated', 'i') ||
# REGEX(?paLabel, '^bstvs', 'i') ||
# REGEX(?paLabel, '^ndv', 'i') ||
# REGEX(?paLabel, '^viable', 'i') ||
# REGEX(?paLabel, '^implications', 'i') ||
# REGEX(?paLabel, '^camels', 'i') ||
# REGEX(?paLabel, '^pcr-reactions', 'i') ||
# REGEX(?paLabel, '^heparan', 'i') ||
# REGEX(?paLabel, '^node', 'i') ||
# REGEX(?paLabel, '^ifitms', 'i') ||
# REGEX(?paLabel, '^isothermal', 'i') ||
# REGEX(?paLabel, '^rbct', 'i') ||
# REGEX(?paLabel, '^lining', 'i') ||
# REGEX(?paLabel, '^sporadic', 'i') ||
# REGEX(?paLabel, '^risks', 'i') ||
# REGEX(?paLabel, '^rabv', 'i') ||
# REGEX(?paLabel, '^permeability', 'i') ||
# REGEX(?paLabel, '^insults', 'i') ||
# REGEX(?paLabel, '^bocv', 'i') ||
# REGEX(?paLabel, '^methods', 'i') ||
# REGEX(?paLabel, '^aetiology', 'i') ||
# REGEX(?paLabel, '^singapore', 'i') ||
# REGEX(?paLabel, '^vuvuzelas', 'i') ||
# REGEX(?paLabel, '^ones', 'i') ||
# REGEX(?paLabel, '^residues', 'i') ||
# REGEX(?paLabel, '^parts', 'i') ||
# REGEX(?paLabel, '^placental', 'i') ||
# REGEX(?paLabel, '^subjective', 'i') ||
# REGEX(?paLabel, '^voles', 'i') ||
# REGEX(?paLabel, '^insights', 'i') ||
# REGEX(?paLabel, '^african', 'i') ||
# REGEX(?paLabel, '^gof', 'i') ||
# REGEX(?paLabel, '^spinal', 'i') ||
# REGEX(?paLabel, '^antigens', 'i') ||
# REGEX(?paLabel, '^causal', 'i') ||
# REGEX(?paLabel, '^astv', 'i') ||
# REGEX(?paLabel, '^large-del', 'i') ||
# REGEX(?paLabel, '^bovine', 'i') ||
# REGEX(?paLabel, '^evt', 'i') ||
# REGEX(?paLabel, '^spherules', 'i') ||
# REGEX(?paLabel, '^covmpro', 'i') ||
# REGEX(?paLabel, '^thymocyte', 'i') ||
# REGEX(?paLabel, '^lcmv', 'i') ||
# REGEX(?paLabel, '^dehydration', 'i') ||
# REGEX(?paLabel, '^antibody', 'i') ||
# REGEX(?paLabel, '^chb', 'i') ||
# REGEX(?paLabel, '^hundreds', 'i') ||
# REGEX(?paLabel, '^orthomyxovirus', 'i') ||
# REGEX(?paLabel, '^horses', 'i') ||
# REGEX(?paLabel, '^drug', 'i') ||
# REGEX(?paLabel, '^proteases', 'i') ||
# REGEX(?paLabel, '^camel', 'i') ||
# REGEX(?paLabel, '^cancers', 'i') ||
# REGEX(?paLabel, '^crp', 'i') ||
# REGEX(?paLabel, '^discussions', 'i') ||
# REGEX(?paLabel, '^causes', 'i') ||
# REGEX(?paLabel, '^conflicting', 'i') ||
# REGEX(?paLabel, '^diagnostic', 'i') ||
# REGEX(?paLabel, '^conceptual', 'i') ||
# REGEX(?paLabel, '^mycoplasma', 'i') ||
# REGEX(?paLabel, '^ifn', 'i') ||
# REGEX(?paLabel, '^influences', 'i') ||
# REGEX(?paLabel, '^sorting', 'i') ||
# REGEX(?paLabel, '^deubiquitinating', 'i') ||
# REGEX(?paLabel, '^treg', 'i') ||
# REGEX(?paLabel, '^synergistic', 'i') ||
# REGEX(?paLabel, '^dimorphic', 'i') ||
# REGEX(?paLabel, '^co-evolution', 'i') ||
# REGEX(?paLabel, '^asymptomatic', 'i') ||
# REGEX(?paLabel, '^oligodendrocytes', 'i') ||
# REGEX(?paLabel, '^downregulation', 'i') ||
# REGEX(?paLabel, '^taxonomy', 'i') ||
# REGEX(?paLabel, '^lymphocytes', 'i') ||
# REGEX(?paLabel, '^countries', 'i') ||
# REGEX(?paLabel, '^causality', 'i') ||
# REGEX(?paLabel, '^morphotype', 'i') ||
# REGEX(?paLabel, '^kawasaki', 'i') ||
# REGEX(?paLabel, '^real-time', 'i') ||
# REGEX(?paLabel, '^untranslated', 'i') ||
# REGEX(?paLabel, '^follow-up', 'i') ||
# REGEX(?paLabel, '^origins', 'i') ||
# REGEX(?paLabel, '^proteome', 'i') ||
# REGEX(?paLabel, '^analytic', 'i') ||
# REGEX(?paLabel, '^regression', 'i') ||
# REGEX(?paLabel, '^microglial', 'i') ||
# REGEX(?paLabel, '^imperfections', 'i') ||
# REGEX(?paLabel, '^fibrinolysis', 'i') ||
# REGEX(?paLabel, '^frameworks', 'i') ||
# REGEX(?paLabel, '^cxr', 'i') ||
# REGEX(?paLabel, '^ingestive', 'i') ||
# REGEX(?paLabel, '^volumes', 'i') ||
# REGEX(?paLabel, '^collectrin', 'i') ||
# REGEX(?paLabel, '^breadth', 'i') ||
# REGEX(?paLabel, '^outbreaks', 'i') ||
# REGEX(?paLabel, '^rigorous', 'i') ||
# REGEX(?paLabel, '^ptm', 'i') ||
# REGEX(?paLabel, '^necrosis', 'i') ||
# REGEX(?paLabel, '^superantigen', 'i') ||
# REGEX(?paLabel, '^maturation', 'i') ||
# REGEX(?paLabel, '^documented', 'i') ||
# REGEX(?paLabel, '^broader', 'i') ||
# REGEX(?paLabel, '^co-infection', 'i') ||
# REGEX(?paLabel, '^lactate', 'i') ||
# REGEX(?paLabel, '^blood-based', 'i') ||
# REGEX(?paLabel, '^tace', 'i') ||
# REGEX(?paLabel, '^accumulation', 'i') ||
# REGEX(?paLabel, '^gammacoronaviruses', 'i') ||
# REGEX(?paLabel, '^rabies', 'i') ||
# REGEX(?paLabel, '^breaths', 'i') ||
# REGEX(?paLabel, '^trends', 'i') ||
# REGEX(?paLabel, '^filariasis', 'i') ||
# REGEX(?paLabel, '^pseudoknot', 'i') ||
# REGEX(?paLabel, '^activities', 'i') ||
# REGEX(?paLabel, '^epidermal', 'i') ||
# REGEX(?paLabel, '^resistant', 'i') ||
# REGEX(?paLabel, '^recombinant', 'i') ||
# REGEX(?paLabel, '^trials', 'i') ||
# REGEX(?paLabel, '^zuk', 'i') ||
# REGEX(?paLabel, '^hcmv', 'i') ||
# REGEX(?paLabel, '^tools', 'i') ||
# REGEX(?paLabel, '^genotype', 'i') ||
# REGEX(?paLabel, '^quarantine', 'i') ||
# REGEX(?paLabel, '^antimalarial', 'i') ||
# REGEX(?paLabel, '^zikv', 'i') ||
# REGEX(?paLabel, '^interruption', 'i') ||
# REGEX(?paLabel, '^assumptions', 'i') ||
# REGEX(?paLabel, '^sets', 'i') ||
# REGEX(?paLabel, '^pharmacology', 'i') ||
# REGEX(?paLabel, '^onfh', 'i') ||
# REGEX(?paLabel, '^ancestors', 'i') ||
# REGEX(?paLabel, '^ternary', 'i') ||
# REGEX(?paLabel, '^populations', 'i') ||
# REGEX(?paLabel, '^periodontal', 'i') ||
# REGEX(?paLabel, '^advantages', 'i') ||
# REGEX(?paLabel, '^deletions', 'i') ||
# REGEX(?paLabel, '^propagation', 'i') ||
# REGEX(?paLabel, '^stimulatory', 'i') ||
# REGEX(?paLabel, '^optimism', 'i') ||
# REGEX(?paLabel, '^ari', 'i') ||
# REGEX(?paLabel, '^scientists', 'i') ||
# REGEX(?paLabel, '^tyrosine', 'i') ||
# REGEX(?paLabel, '^bcov', 'i') ||
# REGEX(?paLabel, '^confirmation', 'i') ||
# REGEX(?paLabel, '^olfactory', 'i') ||
# REGEX(?paLabel, '^enterocytes', 'i') ||
# REGEX(?paLabel, '^vesicles', 'i') ||
# REGEX(?paLabel, '^flaviviridae', 'i') ||
# REGEX(?paLabel, '^dmog', 'i') ||
# REGEX(?paLabel, '^signaling', 'i') ||
# REGEX(?paLabel, '^confirming', 'i') ||
# REGEX(?paLabel, '^lethal', 'i') ||
# REGEX(?paLabel, '^americans', 'i') ||
# REGEX(?paLabel, '^gibbons', 'i') ||
# REGEX(?paLabel, '^genomes', 'i') ||
# REGEX(?paLabel, '^phosphatidylethanolamine', 'i') ||
# REGEX(?paLabel, '^tested', 'i') ||
# REGEX(?paLabel, '^phenotypes', 'i') ||
# REGEX(?paLabel, '^progression', 'i') ||
# REGEX(?paLabel, '^cytotoxicity', 'i') ||
# REGEX(?paLabel, '^basigin', 'i') ||
# REGEX(?paLabel, '^vivo', 'i') ||
# REGEX(?paLabel, '^nsaids', 'i') ||
# REGEX(?paLabel, '^colleagues', 'i') ||
# REGEX(?paLabel, '^opposing', 'i') ||
# REGEX(?paLabel, '^corticosteroid', 'i') ||
# REGEX(?paLabel, '^mammary', 'i') ||
# REGEX(?paLabel, '^low-fidelity', 'i') ||
# REGEX(?paLabel, '^genome', 'i') ||
# REGEX(?paLabel, '^restrictions', 'i') ||
# REGEX(?paLabel, '^fipv', 'i') ||
# REGEX(?paLabel, '^intrahost', 'i') ||
# REGEX(?paLabel, '^outbreak', 'i') ||
# REGEX(?paLabel, '^inactivated', 'i') ||
# REGEX(?paLabel, '^zoo', 'i') ||
# REGEX(?paLabel, '^circulating', 'i') ||
# REGEX(?paLabel, '^materials', 'i') ||
# REGEX(?paLabel, '^beneficial', 'i') ||
# REGEX(?paLabel, '^professionals', 'i') ||
# REGEX(?paLabel, '^absent', 'i') ||
# REGEX(?paLabel, '^aom', 'i') ||
# REGEX(?paLabel, '^epidemiology', 'i') ||
# REGEX(?paLabel, '^pneumoniae', 'i') ||
# REGEX(?paLabel, '^trophoblast', 'i') ||
# REGEX(?paLabel, '^june', 'i') ||
# REGEX(?paLabel, '^transgene', 'i') ||
# REGEX(?paLabel, '^marrow', 'i') ||
# REGEX(?paLabel, '^thymic', 'i') ||
# REGEX(?paLabel, '^immunological', 'i') ||
# REGEX(?paLabel, '^meteorological', 'i') ||
# REGEX(?paLabel, '^proteosome-sensitive', 'i') ||
# REGEX(?paLabel, '^fecv', 'i') ||
# REGEX(?paLabel, '^nss', 'i') ||
# REGEX(?paLabel, '^pharmaceuticals', 'i') ||
# REGEX(?paLabel, '^rna', 'i') ||
# REGEX(?paLabel, '^suilysin', 'i') ||
# REGEX(?paLabel, '^amplification', 'i') ||
# REGEX(?paLabel, '^plpro', 'i') ||
# REGEX(?paLabel, '^neurona', 'i') ||
# REGEX(?paLabel, '^transient', 'i') ||
# REGEX(?paLabel, '^religiosity', 'i') ||
# REGEX(?paLabel, '^capabilities', 'i') ||
# REGEX(?paLabel, '^mature', 'i') ||
# REGEX(?paLabel, '^sarsr-covs', 'i') ||
# REGEX(?paLabel, '^empyema', 'i') ||
# REGEX(?paLabel, '^genomic', 'i') ||
# REGEX(?paLabel, '^rnai-like', 'i') ||
# REGEX(?paLabel, '^protracted', 'i') ||
# REGEX(?paLabel, '^turnover', 'i') ||
# REGEX(?paLabel, '^mirna', 'i') ||
# REGEX(?paLabel, '^dehydrogenase', 'i') ||
# REGEX(?paLabel, '^machinery', 'i') ||
# REGEX(?paLabel, '^proteins', 'i') ||
# REGEX(?paLabel, '^evidences', 'i') ||
# REGEX(?paLabel, '^bronchiolitis', 'i') ||
# REGEX(?paLabel, '^earliest', 'i') ||
# REGEX(?paLabel, '^occurrence', 'i') ||
# REGEX(?paLabel, '^manifestation', 'i') ||
# REGEX(?paLabel, '^weeks', 'i') ||
# REGEX(?paLabel, '^antitumor', 'i') ||
# REGEX(?paLabel, '^systematic', 'i') ||
# REGEX(?paLabel, '^mammals', 'i') ||
# REGEX(?paLabel, '^antiretroviral', 'i') ||
# REGEX(?paLabel, '^intravenous', 'i') ||
# REGEX(?paLabel, '^mediator', 'i') ||
# REGEX(?paLabel, '^apoptotic', 'i') ||
# REGEX(?paLabel, '^badgers', 'i') ||
# REGEX(?paLabel, '^discovered', 'i') ||
# REGEX(?paLabel, '^docking', 'i') ||
# REGEX(?paLabel, '^prematurity', 'i') ||
# REGEX(?paLabel, '^tcr', 'i') ||
# REGEX(?paLabel, '^pathogen', 'i') ||
# REGEX(?paLabel, '^ehec', 'i') ||
# REGEX(?paLabel, '^lps', 'i') ||
# REGEX(?paLabel, '^lineages', 'i') ||
# REGEX(?paLabel, '^subtypes', 'i') ||
# REGEX(?paLabel, '^vero', 'i') ||
# REGEX(?paLabel, '^heterogeneity', 'i') ||
# REGEX(?paLabel, '^inhibits', 'i') ||
# REGEX(?paLabel, '^timeframes', 'i') ||
# REGEX(?paLabel, '^rtis', 'i') ||
# REGEX(?paLabel, '^immunomodulatory', 'i') ||
# REGEX(?paLabel, '^oscillation', 'i') ||
# REGEX(?paLabel, '^virus-host', 'i') ||
# REGEX(?paLabel, '^inability', 'i') ||
# REGEX(?paLabel, '^versions', 'i') ||
# REGEX(?paLabel, '^community-acquired', 'i') ||
# REGEX(?paLabel, '^sloppiness', 'i') ||
# REGEX(?paLabel, '^mating', 'i') ||
# REGEX(?paLabel, '^decoy', 'i') ||
# REGEX(?paLabel, '^mimicry', 'i') ||
# REGEX(?paLabel, '^pathophysiology', 'i') ||
# REGEX(?paLabel, '^yagouaroundi', 'i') ||
# REGEX(?paLabel, '^tmev', 'i') ||
# REGEX(?paLabel, '^interferons', 'i') ||
# REGEX(?paLabel, '^felv', 'i') ||
# REGEX(?paLabel, '^cases', 'i') ||
# REGEX(?paLabel, '^efforts', 'i') ||
# REGEX(?paLabel, '^variants', 'i') ||
# REGEX(?paLabel, '^biosafety', 'i') ||
# REGEX(?paLabel, '^o-acetylesterases', 'i') ||
# REGEX(?paLabel, '^restricted', 'i') ||
# REGEX(?paLabel, '^exacerbations', 'i') ||
# REGEX(?paLabel, '^immunization', 'i') ||
# REGEX(?paLabel, '^viruses', 'i') ||
# REGEX(?paLabel, '^coated', 'i') ||
# REGEX(?paLabel, '^non-lethal', 'i') ||
# REGEX(?paLabel, '^mutations', 'i') ||
# REGEX(?paLabel, '^quercetin', 'i') ||
# REGEX(?paLabel, '^probit', 'i') ||
# REGEX(?paLabel, '^tryptophan', 'i') ||
# REGEX(?paLabel, '^clad', 'i') ||
# REGEX(?paLabel, '^metastasis', 'i') ||
# REGEX(?paLabel, '^surrogate', 'i') ||
# REGEX(?paLabel, '^assay', 'i') ||
# REGEX(?paLabel, '^continental', 'i') ||
# REGEX(?paLabel, '^evolutionary-based', 'i') ||
# REGEX(?paLabel, '^leptospira-induced', 'i') ||
# REGEX(?paLabel, '^vzv', 'i') ||
# REGEX(?paLabel, '^retinopathy', 'i') ||
# REGEX(?paLabel, '^cell-mediated', 'i') ||
# REGEX(?paLabel, '^indirect', 'i') ||
# REGEX(?paLabel, '^constraints', 'i') ||
# REGEX(?paLabel, '^fip', 'i') ||
# REGEX(?paLabel, '^multigroup', 'i') ||
# REGEX(?paLabel, '^uganda', 'i') ||
# REGEX(?paLabel, '^viral-bacterial', 'i') ||
# REGEX(?paLabel, '^hematopoietic', 'i') ||
# REGEX(?paLabel, '^collaborators', 'i') ||
# REGEX(?paLabel, '^mrna', 'i') ||
# REGEX(?paLabel, '^serum', 'i') ||
# REGEX(?paLabel, '^preludes', 'i') ||
# REGEX(?paLabel, '^enzymes', 'i') ||
# REGEX(?paLabel, '^coronaviruses', 'i') ||
# REGEX(?paLabel, '^nonstructural', 'i') ||
# REGEX(?paLabel, '^lymphocyte', 'i') ||
# REGEX(?paLabel, '^bronchitis', 'i') ||
# REGEX(?paLabel, '^disparity', 'i') ||
# REGEX(?paLabel, '^profiles', 'i') ||
# REGEX(?paLabel, '^resonance', 'i') ||
# REGEX(?paLabel, '^gastroenteritis', 'i') ||
# REGEX(?paLabel, '^inflammation', 'i') ||
# REGEX(?paLabel, '^plasmacytoid', 'i') ||
# REGEX(?paLabel, '^conceptualization', 'i') ||
# REGEX(?paLabel, '^ubiquitous', 'i') ||
# REGEX(?paLabel, '^receptor-', 'i') ||
# REGEX(?paLabel, '^glioma', 'i') ||
# REGEX(?paLabel, '^exacerbation', 'i') ||
# REGEX(?paLabel, '^abdominal', 'i') ||
# REGEX(?paLabel, '^thailand', 'i') ||
# REGEX(?paLabel, '^scales', 'i') ||
# REGEX(?paLabel, '^tapcs', 'i') ||
# REGEX(?paLabel, '^dephosphorylation', 'i') ||
# REGEX(?paLabel, '^lipopolysaccharide', 'i') ||
# REGEX(?paLabel, '^libraries', 'i') ||
# REGEX(?paLabel, '^ifng', 'i') ||
# REGEX(?paLabel, '^antigen', 'i') ||
# REGEX(?paLabel, '^protease', 'i') ||
# REGEX(?paLabel, '^iran', 'i') ||
# REGEX(?paLabel, '^regulators', 'i') ||
# REGEX(?paLabel, '^bcrp', 'i') ||
# REGEX(?paLabel, '^contributes', 'i') ||
# REGEX(?paLabel, '^datasets', 'i') ||
# REGEX(?paLabel, '^hybridization', 'i') ||
# REGEX(?paLabel, '^developed', 'i') ||
# REGEX(?paLabel, '^baseline', 'i') ||
# REGEX(?paLabel, '^symptoms', 'i') ||
# REGEX(?paLabel, '^humans', 'i') ||
# REGEX(?paLabel, '^non-enterotropic', 'i') ||
# REGEX(?paLabel, '^fragments', 'i') ||
# REGEX(?paLabel, '^neurologic', 'i') ||
# REGEX(?paLabel, '^inoculum', 'i') ||
# REGEX(?paLabel, '^gag', 'i') ||
# REGEX(?paLabel, '^dividing', 'i') ||
# REGEX(?paLabel, '^airflow', 'i') ||
# REGEX(?paLabel, '^bat-maintenance', 'i') ||
# REGEX(?paLabel, '^zinkernagel', 'i') ||
# REGEX(?paLabel, '^fcovs', 'i') ||
# REGEX(?paLabel, '^producers', 'i') ||
# REGEX(?paLabel, '^syntaxin', 'i') ||
# REGEX(?paLabel, '^precursors', 'i') ||
# REGEX(?paLabel, '^template', 'i') ||
# REGEX(?paLabel, '^dairy', 'i') ||
# REGEX(?paLabel, '^precipitation', 'i') ||
# REGEX(?paLabel, '^inhibitory', 'i') ||
# REGEX(?paLabel, '^crosstalk', 'i') ||
# REGEX(?paLabel, '^highlights', 'i') ||
# REGEX(?paLabel, '^positively', 'i') ||
# REGEX(?paLabel, '^dubs', 'i') ||
# REGEX(?paLabel, '^subsite', 'i') ||
# REGEX(?paLabel, '^pneumonia', 'i') ||
# REGEX(?paLabel, '^infants', 'i') ||
# REGEX(?paLabel, '^tier', 'i') ||
# REGEX(?paLabel, '^health-care', 'i') ||
# REGEX(?paLabel, '^gland', 'i') ||
# REGEX(?paLabel, '^stem-loop', 'i') ||
# REGEX(?paLabel, '^dissemination', 'i') ||
# REGEX(?paLabel, '^diarrhoea', 'i') ||
# REGEX(?paLabel, '^beliefs', 'i') ||
# REGEX(?paLabel, '^tissues', 'i') ||
# REGEX(?paLabel, '^evolutionary', 'i') ||
# REGEX(?paLabel, '^promiscuous', 'i') ||
# REGEX(?paLabel, '^diagnostics', 'i') ||
# REGEX(?paLabel, '^tract', 'i') ||
# REGEX(?paLabel, '^stochastic', 'i') ||
# REGEX(?paLabel, '^a-count', 'i') ||
# REGEX(?paLabel, '^hcvcc', 'i') ||
# REGEX(?paLabel, '^autism', 'i') ||
# REGEX(?paLabel, '^regions', 'i') ||
# REGEX(?paLabel, '^intake', 'i') ||
# REGEX(?paLabel, '^membrane', 'i') ||
# REGEX(?paLabel, '^niemann', 'i') ||
# REGEX(?paLabel, '^microcephaly', 'i') ||
# REGEX(?paLabel, '^domains', 'i') ||
# REGEX(?paLabel, '^igs', 'i') ||
# REGEX(?paLabel, '^cyanocobalamin', 'i') ||
# REGEX(?paLabel, '^permutation', 'i') ||
# REGEX(?paLabel, '^fluidity', 'i') ||
# REGEX(?paLabel, '^pandemic', 'i') ||
# REGEX(?paLabel, '^myeloid', 'i') ||
# REGEX(?paLabel, '^indels', 'i') ||
# REGEX(?paLabel, '^adherence', 'i') ||
# REGEX(?paLabel, '^high-symptom', 'i') ||
# REGEX(?paLabel, '^pulmonary', 'i') ||
# REGEX(?paLabel, '^subset', 'i') ||
# REGEX(?paLabel, '^igg', 'i') ||
# REGEX(?paLabel, '^persistence', 'i') ||
# REGEX(?paLabel, '^suspected', 'i') ||
# REGEX(?paLabel, '^incidence', 'i') ||
# REGEX(?paLabel, '^expressions', 'i') ||
# REGEX(?paLabel, '^conclusions', 'i') ||
# REGEX(?paLabel, '^shedding', 'i') ||
# REGEX(?paLabel, '^culture-adapted', 'i') ||
# REGEX(?paLabel, '^civets', 'i') ||
# REGEX(?paLabel, '^axis', 'i') ||
# REGEX(?paLabel, '^vector', 'i') ||
# REGEX(?paLabel, '^piglets', 'i') ||
# REGEX(?paLabel, '^agonist', 'i') ||
# REGEX(?paLabel, '^prevalence', 'i') ||
# REGEX(?paLabel, '^antioxidant', 'i') ||
# REGEX(?paLabel, '^cultures', 'i') ||
# REGEX(?paLabel, '^pbc', 'i') ||
# REGEX(?paLabel, '^lumen', 'i') ||
# REGEX(?paLabel, '^hearts', 'i') ||
# REGEX(?paLabel, '^emphysema', 'i') ||
# REGEX(?paLabel, '^cardiac', 'i') ||
# REGEX(?paLabel, '^chondroitin', 'i') ||
# REGEX(?paLabel, '^foothold', 'i') ||
# REGEX(?paLabel, '^dampening', 'i') ||
# REGEX(?paLabel, '^genome-wide', 'i') ||
# REGEX(?paLabel, '^mbsr', 'i') ||
# REGEX(?paLabel, '^endemic', 'i') ||
# REGEX(?paLabel, '^eae', 'i') ||
# REGEX(?paLabel, '^deficiencies', 'i') ||
# REGEX(?paLabel, '^findings', 'i') ||
# REGEX(?paLabel, '^ion', 'i') ||
# REGEX(?paLabel, '^araneus', 'i') ||
# REGEX(?paLabel, '^ticks', 'i') ||
# REGEX(?paLabel, '^anti-cancer', 'i') ||
# REGEX(?paLabel, '^complementarity', 'i') ||
# REGEX(?paLabel, '^affymetrix', 'i') ||
# REGEX(?paLabel, '^mitochondrion', 'i') ||
# REGEX(?paLabel, '^times', 'i') ||
# REGEX(?paLabel, '^ngal', 'i') ||
# REGEX(?paLabel, '^cooling', 'i') ||
# REGEX(?paLabel, '^proteosome-resistant', 'i') ||
# REGEX(?paLabel, '^submucosa', 'i') ||
# REGEX(?paLabel, '^herein', 'i') ||
# REGEX(?paLabel, '^hypothesized', 'i') ||
# REGEX(?paLabel, '^antigenic', 'i') ||
# REGEX(?paLabel, '^onset', 'i') ||
# REGEX(?paLabel, '^sirna', 'i') ||
# REGEX(?paLabel, '^rnase', 'i') ||
# REGEX(?paLabel, '^algorithm', 'i') ||
# REGEX(?paLabel, '^undergoing', 'i') ||
# REGEX(?paLabel, '^s-adenosylmethionine', 'i') ||
# REGEX(?paLabel, '^mothers', 'i') ||
# REGEX(?paLabel, '^nephropathy', 'i') ||
# REGEX(?paLabel, '^homozygosity', 'i') ||
# REGEX(?paLabel, '^renin', 'i') ||
# REGEX(?paLabel, '^stronger', 'i') ||
# REGEX(?paLabel, '^viraemia', 'i') ||
# REGEX(?paLabel, '^potent', 'i') ||
# REGEX(?paLabel, '^complexes', 'i') ||
# REGEX(?paLabel, '^connective', 'i') ||
# REGEX(?paLabel, '^mechanistic', 'i') ||
# REGEX(?paLabel, '^reemerging', 'i') ||
# REGEX(?paLabel, '^factors', 'i') ||
# REGEX(?paLabel, '^strategies', 'i') ||
# REGEX(?paLabel, '^intensive', 'i') ||
# REGEX(?paLabel, '^antiviral', 'i') ||
# REGEX(?paLabel, '^carcinogenesis', 'i') ||
# REGEX(?paLabel, '^therapies', 'i') ||
# REGEX(?paLabel, '^probiotic', 'i') ||
# REGEX(?paLabel, '^vnas', 'i') ||
# REGEX(?paLabel, '^plasma', 'i') ||
# REGEX(?paLabel, '^biochemical', 'i') ||
# REGEX(?paLabel, '^chymotrypsin-like', 'i') ||
# REGEX(?paLabel, '^cross-sectional', 'i') ||
# REGEX(?paLabel, '^galv', 'i') ||
# REGEX(?paLabel, '^scrutiny', 'i') ||
# REGEX(?paLabel, '^ten-year', 'i') ||
# REGEX(?paLabel, '^stnx', 'i') ||
# REGEX(?paLabel, '^repercussions', 'i') ||
# REGEX(?paLabel, '^anionic', 'i') ||
# REGEX(?paLabel, '^nstvs', 'i') ||
# REGEX(?paLabel, '^ebv-driven', 'i') ||
# REGEX(?paLabel, '^multi-factorial', 'i') ||
# REGEX(?paLabel, '^ascs', 'i') ||
# REGEX(?paLabel, '^simulation', 'i') ||
# REGEX(?paLabel, '^handles', 'i') ||
# REGEX(?paLabel, '^pecorum', 'i') ||
# REGEX(?paLabel, '^transfection', 'i') ||
# REGEX(?paLabel, '^epidermis', 'i') ||
# REGEX(?paLabel, '^innate', 'i') ||
# REGEX(?paLabel, '^isolates', 'i') ||
# REGEX(?paLabel, '^torsional', 'i') ||
# REGEX(?paLabel, '^imports', 'i') ||
# REGEX(?paLabel, '^infectivity', 'i') ||
# REGEX(?paLabel, '^gradual', 'i') ||
# REGEX(?paLabel, '^immature', 'i') ||
# REGEX(?paLabel, '^shap', 'i') ||
# REGEX(?paLabel, '^contaminated', 'i') ||
# REGEX(?paLabel, '^inhaled', 'i') ||
# REGEX(?paLabel, '^pathology', 'i') ||
# REGEX(?paLabel, '^modelling', 'i') ||
# REGEX(?paLabel, '^trachomatis', 'i') ||
# REGEX(?paLabel, '^observations', 'i') ||
# REGEX(?paLabel, '^substrate', 'i') ||
# REGEX(?paLabel, '^cell-receptor', 'i') ||
# REGEX(?paLabel, '^geographically', 'i') ||
# REGEX(?paLabel, '^sero-prevalence', 'i') ||
# REGEX(?paLabel, '^patients', 'i') ||
# REGEX(?paLabel, '^variations', 'i') ||
# REGEX(?paLabel, '^heuristic', 'i') ||
# REGEX(?paLabel, '^salmonella', 'i') ||
# REGEX(?paLabel, '^institute', 'i') ||
# REGEX(?paLabel, '^dtu', 'i') ||
# REGEX(?paLabel, '^curvature', 'i') ||
# REGEX(?paLabel, '^recurrence', 'i') ||
# REGEX(?paLabel, '^ntp-dependent', 'i') ||
# REGEX(?paLabel, '^focused', 'i') ||
# REGEX(?paLabel, '^cov', 'i') ||
# REGEX(?paLabel, '^operations', 'i') ||
# REGEX(?paLabel, '^varying', 'i') ||
# REGEX(?paLabel, '^descriptive', 'i') ||
# REGEX(?paLabel, '^multi-disciplinary', 'i') ||
# REGEX(?paLabel, '^neonatal', 'i') ||
# REGEX(?paLabel, '^vivo-morpholinos', 'i') ||
# REGEX(?paLabel, '^segmentation', 'i') ||
# REGEX(?paLabel, '^mhc', 'i') ||
# REGEX(?paLabel, '^kinases', 'i') ||
# REGEX(?paLabel, '^cheetah', 'i') ||
# REGEX(?paLabel, '^disruption', 'i') ||
# REGEX(?paLabel, '^azithromycin', 'i') ||
# REGEX(?paLabel, '^oxide', 'i') ||
# REGEX(?paLabel, '^anti-cat', 'i') ||
# REGEX(?paLabel, '^disorders', 'i') ||
# REGEX(?paLabel, '^smokers', 'i') ||
# REGEX(?paLabel, '^horizontal', 'i') ||
# REGEX(?paLabel, '^pathogenesis', 'i') ||
# REGEX(?paLabel, '^oxidation', 'i') ||
# REGEX(?paLabel, '^patterns', 'i') ||
# REGEX(?paLabel, '^complication', 'i') ||
# REGEX(?paLabel, '^substantive', 'i') ||
# REGEX(?paLabel, '^fecal', 'i') ||
# REGEX(?paLabel, '^ghanaian', 'i') ||
# REGEX(?paLabel, '^catalytic', 'i') ||
# REGEX(?paLabel, '^unfolding', 'i') ||
# REGEX(?paLabel, '^comorbidity', 'i') ||
# REGEX(?paLabel, '^chikv', 'i') ||
# REGEX(?paLabel, '^deft', 'i') ||
# REGEX(?paLabel, '^prime-boost', 'i') ||
# REGEX(?paLabel, '^mtct', 'i') ||
# REGEX(?paLabel, '^qtl', 'i') ||
# REGEX(?paLabel, '^ctsl', 'i') ||
# REGEX(?paLabel, '^allograft', 'i') ||
# REGEX(?paLabel, '^etiology', 'i') ||
# REGEX(?paLabel, '^immunoglobulins', 'i') ||
# REGEX(?paLabel, '^markedly', 'i') ||
# REGEX(?paLabel, '^invasive', 'i') ||
# REGEX(?paLabel, '^interviews', 'i') ||
# REGEX(?paLabel, '^graft', 'i') ||
# REGEX(?paLabel, '^cyclophilin', 'i') ||
# REGEX(?paLabel, '^superimposed', 'i') ||
# REGEX(?paLabel, '^forgo', 'i') ||
# REGEX(?paLabel, '^tasks', 'i') ||
# REGEX(?paLabel, '^helix', 'i') ||
# REGEX(?paLabel, '^unbound', 'i') ||
# REGEX(?paLabel, '^adaptation', 'i') ||
# REGEX(?paLabel, '^unrepaired', 'i') ||
# REGEX(?paLabel, '^matured', 'i') ||
# REGEX(?paLabel, '^secretory', 'i') ||
# REGEX(?paLabel, '^snp', 'i') ||
# REGEX(?paLabel, '^extrinsic', 'i') ||
# REGEX(?paLabel, '^disturbance', 'i') ||
# REGEX(?paLabel, '^pedv-induced', 'i') ||
# REGEX(?paLabel, '^fiv', 'i') ||
# REGEX(?paLabel, '^zoogeographical', 'i') ||
# REGEX(?paLabel, '^adaptive', 'i') ||
# REGEX(?paLabel, '^cytopathic', 'i') ||
# REGEX(?paLabel, '^geography', 'i') ||
# REGEX(?paLabel, '^aims', 'i') ||
# REGEX(?paLabel, '^binding', 'i') ||
# REGEX(?paLabel, '^herd', 'i') ||
# REGEX(?paLabel, '^helical', 'i') ||
# REGEX(?paLabel, '^aibv', 'i') ||
# REGEX(?paLabel, '^structurally', 'i') ||
# REGEX(?paLabel, '^cids', 'i') ||
# REGEX(?paLabel, '^stretches', 'i') ||
# REGEX(?paLabel, '^aecs', 'i') ||
# REGEX(?paLabel, '^aceturate', 'i') ||
# REGEX(?paLabel, '^copies', 'i') ||
# REGEX(?paLabel, '^post-blood', 'i') ||
# REGEX(?paLabel, '^catabolism', 'i') ||
# REGEX(?paLabel, '^diminazene', 'i') ||
# REGEX(?paLabel, '^ntp-binding', 'i') ||
# REGEX(?paLabel, '^span', 'i') ||
# REGEX(?paLabel, '^isavirus', 'i') ||
# REGEX(?paLabel, '^arthritic', 'i') ||
# REGEX(?paLabel, '^renin-angiotensin', 'i') ||
# REGEX(?paLabel, '^transmembrane', 'i') ||
# REGEX(?paLabel, '^panmictic', 'i') ||
# REGEX(?paLabel, '^resulting', 'i') ||
# REGEX(?paLabel, '^hydrophobic', 'i') ||
# REGEX(?paLabel, '^bundles', 'i') ||
# REGEX(?paLabel, '^dual', 'i') ||
# REGEX(?paLabel, '^parvoviruses', 'i') ||
# REGEX(?paLabel, '^signs', 'i') ||
# REGEX(?paLabel, '^ppar', 'i') ||
# REGEX(?paLabel, '^genera', 'i') ||
# REGEX(?paLabel, '^norovirus', 'i') ||
# REGEX(?paLabel, '^allostery', 'i') ||
# REGEX(?paLabel, '^nsg', 'i') ||
# REGEX(?paLabel, '^platelet', 'i') ||
# REGEX(?paLabel, '^oasl', 'i') ||
# REGEX(?paLabel, '^polyvalent', 'i') ||
# REGEX(?paLabel, '^maternal', 'i') ||
# REGEX(?paLabel, '^pmps', 'i') ||
# REGEX(?paLabel, '^hypertension', 'i') ||
# REGEX(?paLabel, '^nasopharyngeal', 'i') ||
# REGEX(?paLabel, '^ali', 'i') ||
# REGEX(?paLabel, '^efficacy', 'i') ||
# REGEX(?paLabel, '^cellular', 'i') ||
# REGEX(?paLabel, '^homologous', 'i') ||
# REGEX(?paLabel, '^poliovirus', 'i') ||
# REGEX(?paLabel, '^organizations', 'i') ||
# REGEX(?paLabel, '^australia', 'i') ||
# REGEX(?paLabel, '^contacts', 'i') ||
# REGEX(?paLabel, '^bacterial', 'i') ||
# REGEX(?paLabel, '^intron', 'i') ||
# REGEX(?paLabel, '^supplementation', 'i') ||
# REGEX(?paLabel, '^alterations', 'i') ||
# REGEX(?paLabel, '^bands', 'i') ||
# REGEX(?paLabel, '^deficiency', 'i') ||
# REGEX(?paLabel, '^networks', 'i') ||
# REGEX(?paLabel, '^antagonist', 'i') ||
# REGEX(?paLabel, '^rats', 'i') ||
# REGEX(?paLabel, '^yeast', 'i') ||
# REGEX(?paLabel, '^phosphorylation', 'i') ||
# REGEX(?paLabel, '^large-scale', 'i') ||
# REGEX(?paLabel, '^familial', 'i') ||
# REGEX(?paLabel, '^incoming', 'i') ||
# REGEX(?paLabel, '^dysbiosis', 'i') ||
# REGEX(?paLabel, '^exothermic', 'i') ||
# REGEX(?paLabel, '^knockouts', 'i') ||
# REGEX(?paLabel, '^sulfation', 'i') ||
# REGEX(?paLabel, '^environments', 'i') ||
# REGEX(?paLabel, '^denv', 'i') ||
# REGEX(?paLabel, '^null', 'i') ||
# REGEX(?paLabel, '^virulent', 'i') ||
# REGEX(?paLabel, '^alveolar', 'i') ||
# REGEX(?paLabel, '^chloroquine', 'i') ||
# REGEX(?paLabel, '^avian', 'i') ||
# REGEX(?paLabel, '^single-hit', 'i') ||
# REGEX(?paLabel, '^respiratory', 'i') ||
# REGEX(?paLabel, '^obese', 'i') ||
# REGEX(?paLabel, '^acute', 'i') ||
# REGEX(?paLabel, '^evasion', 'i') ||
# REGEX(?paLabel, '^low-symptom', 'i') ||
# REGEX(?paLabel, '^conclusive', 'i') ||
# REGEX(?paLabel, '^anti-microbial', 'i') ||
# REGEX(?paLabel, '^paralogs', 'i') ||
# REGEX(?paLabel, '^thymocytes', 'i') ||
# REGEX(?paLabel, '^symptomatic', 'i') ||
# REGEX(?paLabel, '^collectins', 'i') ||
# REGEX(?paLabel, '^hong', 'i') ||
# REGEX(?paLabel, '^miniopterus', 'i') ||
# REGEX(?paLabel, '^virus-positive', 'i') ||
# REGEX(?paLabel, '^re-infection', 'i') ||
# REGEX(?paLabel, '^neurological', 'i') ||
# REGEX(?paLabel, '^vaccination', 'i') ||
# REGEX(?paLabel, '^bkv', 'i') ||
# REGEX(?paLabel, '^adrenal', 'i') ||
# REGEX(?paLabel, '^prolonged', 'i') ||
# REGEX(?paLabel, '^heater', 'i') ||
# REGEX(?paLabel, '^neutralizing', 'i') ||
# REGEX(?paLabel, '^superinfection', 'i') ||
# REGEX(?paLabel, '^eosinophil', 'i') ||
# REGEX(?paLabel, '^orderly', 'i') ||
# REGEX(?paLabel, '^astrovirus', 'i') ||
# REGEX(?paLabel, '^simulations', 'i') ||
# REGEX(?paLabel, '^hcov', 'i') ||
# REGEX(?paLabel, '^cadherin', 'i') ||
# REGEX(?paLabel, '^trypanosome', 'i') ||
# REGEX(?paLabel, '^options', 'i') ||
# REGEX(?paLabel, '^fusion', 'i') ||
# REGEX(?paLabel, '^densities', 'i') ||
# REGEX(?paLabel, '^experiments', 'i') ||
# REGEX(?paLabel, '^viral', 'i') ||
# REGEX(?paLabel, '^mannan', 'i') ||
# REGEX(?paLabel, '^rhinoviruses', 'i') ||
# REGEX(?paLabel, '^cockroach', 'i') ||
# REGEX(?paLabel, '^kinase', 'i') ||
# REGEX(?paLabel, '^siv', 'i') ||
# REGEX(?paLabel, '^cytokinemia', 'i') ||
# REGEX(?paLabel, '^sporozoites', 'i') ||
# REGEX(?paLabel, '^recombination', 'i') ||
# REGEX(?paLabel, '^sub-lineages', 'i') ||
# REGEX(?paLabel, '^attenuation', 'i') ||
# REGEX(?paLabel, '^neonate', 'i') ||
# REGEX(?paLabel, '^mannose', 'i') ||
# REGEX(?paLabel, '^autoimmunity', 'i') ||
# REGEX(?paLabel, '^thoracic', 'i') ||
# REGEX(?paLabel, '^longevity', 'i') ||
# REGEX(?paLabel, '^tbev', 'i') ||
# REGEX(?paLabel, '^observed', 'i') ||
# REGEX(?paLabel, '^calves', 'i') ||
# REGEX(?paLabel, '^cps-cq', 'i') ||
# REGEX(?paLabel, '^effector', 'i') ||
# REGEX(?paLabel, '^markers', 'i') ||
# REGEX(?paLabel, '^cleavage', 'i') ||
# REGEX(?paLabel, '^multi-functional', 'i') ||
# REGEX(?paLabel, '^neurons', 'i') ||
# REGEX(?paLabel, '^urine', 'i') ||
# REGEX(?paLabel, '^intestine', 'i') ||
# REGEX(?paLabel, '^sequences', 'i') ||
# REGEX(?paLabel, '^suppression', 'i') ||
# REGEX(?paLabel, '^hrvs', 'i') ||
# REGEX(?paLabel, '^cathepsin', 'i') ||
# REGEX(?paLabel, '^changed', 'i') ||
# REGEX(?paLabel, '^ubiquitin', 'i') ||
# REGEX(?paLabel, '^reports', 'i') ||
# REGEX(?paLabel, '^nitric', 'i') ||
# REGEX(?paLabel, '^frameshift', 'i') ||
# REGEX(?paLabel, '^functions', 'i') ||
# REGEX(?paLabel, '^agonists', 'i') ||
# REGEX(?paLabel, '^declining', 'i') ||
# REGEX(?paLabel, '^ups', 'i') ||
# REGEX(?paLabel, '^plausible', 'i') ||
# REGEX(?paLabel, '^abs', 'i') ||
# REGEX(?paLabel, '^hela', 'i') ||
# REGEX(?paLabel, '^interacting', 'i') ||
# REGEX(?paLabel, '^bundle', 'i') ||
# REGEX(?paLabel, '^genotypic', 'i') ||
# REGEX(?paLabel, '^intestinal', 'i') ||
# REGEX(?paLabel, '^zero-inflated', 'i') ||
# REGEX(?paLabel, '^sequestered', 'i') ||
# REGEX(?paLabel, '^ranavirus', 'i') ||
# REGEX(?paLabel, '^agents', 'i') ||
# REGEX(?paLabel, '^age-matched', 'i') ||
# REGEX(?paLabel, '^passive', 'i') ||
# REGEX(?paLabel, '^anti-prrsv', 'i') ||
# REGEX(?paLabel, '^fret', 'i') ||
# REGEX(?paLabel, '^emergence', 'i') ||
# REGEX(?paLabel, '^lrtis', 'i') ||
# REGEX(?paLabel, '^immunomodulator', 'i') ||
# REGEX(?paLabel, '^mitochondrial', 'i') ||
# REGEX(?paLabel, '^birth-and-death', 'i') ||
# REGEX(?paLabel, '^core-rna', 'i') ||
# REGEX(?paLabel, '^fungus', 'i') ||
# REGEX(?paLabel, '^levels', 'i') ||
# REGEX(?paLabel, '^lipids', 'i') ||
# REGEX(?paLabel, '^rates', 'i') ||
# REGEX(?paLabel, '^microbiota', 'i') ||
# REGEX(?paLabel, '^cortical', 'i') ||
# REGEX(?paLabel, '^similarities', 'i') ||
# REGEX(?paLabel, '^corona-', 'i') ||
# REGEX(?paLabel, '^desmethylicaritin', 'i') ||
# REGEX(?paLabel, '^emr-based', 'i') ||
# REGEX(?paLabel, '^ivig', 'i') ||
# REGEX(?paLabel, '^well-coordinated', 'i') ||
# REGEX(?paLabel, '^proximity', 'i') ||
# REGEX(?paLabel, '^colonized', 'i') ||
# REGEX(?paLabel, '^dormancy', 'i') ||
# REGEX(?paLabel, '^individuals', 'i') ||
# REGEX(?paLabel, '^nec', 'i') ||
# REGEX(?paLabel, '^membranes', 'i') ||
# REGEX(?paLabel, '^genotypes', 'i') ||
# REGEX(?paLabel, '^cvid', 'i') ||
# REGEX(?paLabel, '^postnatal', 'i') ||
# REGEX(?paLabel, '^virulence', 'i') ||
# REGEX(?paLabel, '^infectious', 'i') ||
# REGEX(?paLabel, '^schizotypal', 'i') ||
# REGEX(?paLabel, '^roles', 'i') ||
# REGEX(?paLabel, '^conditions', 'i') ||
# REGEX(?paLabel, '^hepeviridae', 'i') ||
# REGEX(?paLabel, '^hypothesis-driven', 'i') ||
# REGEX(?paLabel, '^recruited', 'i') ||
# REGEX(?paLabel, '^intermediate', 'i') ||
# REGEX(?paLabel, '^lavage', 'i') ||
# REGEX(?paLabel, '^multiplex', 'i') ||
# REGEX(?paLabel, '^coordinated', 'i') ||
# REGEX(?paLabel, '^tcov', 'i') ||
# REGEX(?paLabel, '^jun', 'i') ||
# REGEX(?paLabel, '^parasite', 'i') ||
# REGEX(?paLabel, '^mismatch', 'i') ||
# REGEX(?paLabel, '^arabian', 'i') ||
# REGEX(?paLabel, '^results', 'i') ||
# REGEX(?paLabel, '^cerebrospinal', 'i') ||
# REGEX(?paLabel, '^nucleotide', 'i') ||
# REGEX(?paLabel, '^probability', 'i') ||
# REGEX(?paLabel, '^ses', 'i') ||
# REGEX(?paLabel, '^cert-dependent', 'i') ||
# REGEX(?paLabel, '^truncation', 'i') ||
# REGEX(?paLabel, '^tfs', 'i') ||
# REGEX(?paLabel, '^enhanced', 'i') ||
# REGEX(?paLabel, '^differences', 'i') ||
# REGEX(?paLabel, '^fats', 'i') ||
# REGEX(?paLabel, '^controls', 'i') ||
# REGEX(?paLabel, '^higher', 'i') ||
# REGEX(?paLabel, '^ceramide', 'i') ||
# REGEX(?paLabel, '^provocative', 'i') ||
# REGEX(?paLabel, '^immunoglobulin', 'i') ||
# REGEX(?paLabel, '^elastase', 'i') ||
# REGEX(?paLabel, '^proofreading', 'i') ||
# REGEX(?paLabel, '^proliferation', 'i') ||
# REGEX(?paLabel, '^polymorphisms', 'i') ||
# REGEX(?paLabel, '^variability', 'i') ||
# REGEX(?paLabel, '^long-lasting', 'i') ||
# REGEX(?paLabel, '^peptides', 'i') ||
# REGEX(?paLabel, '^hav', 'i') ||
# REGEX(?paLabel, '^virions', 'i') ||
# REGEX(?paLabel, '^synthesis', 'i') ||
# REGEX(?paLabel, '^highest', 'i') ||
# REGEX(?paLabel, '^proteomic', 'i') ||
# REGEX(?paLabel, '^mauritian', 'i') ||
# REGEX(?paLabel, '^clinically', 'i') ||
# REGEX(?paLabel, '^monocytes', 'i') ||
# REGEX(?paLabel, '^gradient', 'i') ||
# REGEX(?paLabel, '^ribosomal', 'i') ||
# REGEX(?paLabel, '^strengths', 'i') ||
# REGEX(?paLabel, '^expressing', 'i') ||
# REGEX(?paLabel, '^critically', 'i') ||
# REGEX(?paLabel, '^brd', 'i') ||
# REGEX(?paLabel, '^forms', 'i') ||
# REGEX(?paLabel, '^asthma', 'i') ||
# REGEX(?paLabel, '^amino', 'i') ||
# REGEX(?paLabel, '^lectin', 'i') ||
# REGEX(?paLabel, '^teh', 'i') ||
# REGEX(?paLabel, '^ligands', 'i') ||
# REGEX(?paLabel, '^endogenous', 'i') ||
# REGEX(?paLabel, '^titre', 'i') ||
# REGEX(?paLabel, '^outcomes', 'i') ||
# REGEX(?paLabel, '^orthogonal', 'i') ||
# REGEX(?paLabel, '^situ', 'i') ||
# REGEX(?paLabel, '^enteric', 'i') ||
# REGEX(?paLabel, '^negligible', 'i') ||
# REGEX(?paLabel, '^disease', 'i') ||
# REGEX(?paLabel, '^organisms', 'i') ||
# REGEX(?paLabel, '^nucleus', 'i') ||
# REGEX(?paLabel, '^indonesia', 'i') ||
# REGEX(?paLabel, '^incorporation', 'i') ||
# REGEX(?paLabel, '^gilts', 'i') ||
# REGEX(?paLabel, '^seafood', 'i') ||
# REGEX(?paLabel, '^transmissibility', 'i') ||
# REGEX(?paLabel, '^electrolytes', 'i') ||
# REGEX(?paLabel, '^remodeling', 'i') ||
# REGEX(?paLabel, '^years', 'i') ||
# REGEX(?paLabel, '^mixing', 'i') ||
# REGEX(?paLabel, '^activators', 'i') ||
# REGEX(?paLabel, '^pediatric', 'i') ||
# REGEX(?paLabel, '^hms', 'i') ||
# REGEX(?paLabel, '^dams', 'i') ||
# REGEX(?paLabel, '^korv', 'i') ||
# REGEX(?paLabel, '^differential', 'i') ||
# REGEX(?paLabel, '^strains', 'i') ||
# REGEX(?paLabel, '^maturing', 'i') ||
# REGEX(?paLabel, '^computation-derived', 'i') ||
# REGEX(?paLabel, '^replicates', 'i') ||
# REGEX(?paLabel, '^seroprevalence', 'i') ||
# REGEX(?paLabel, '^aerosols', 'i') ||
# REGEX(?paLabel, '^studies', 'i') ||
# REGEX(?paLabel, '^porv', 'i') ||
# REGEX(?paLabel, '^pseudoknots', 'i') ||
# REGEX(?paLabel, '^formulation', 'i') ||
# REGEX(?paLabel, '^positions', 'i') ||
# REGEX(?paLabel, '^fcov-infected', 'i') ||
# REGEX(?paLabel, '^fixation', 'i') ||
# REGEX(?paLabel, '^microglia', 'i') ||
# REGEX(?paLabel, '^crosslinkers', 'i') ||
# REGEX(?paLabel, '^presentations', 'i') ||
# REGEX(?paLabel, '^ctl', 'i') ||
# REGEX(?paLabel, '^primate', 'i') ||
# REGEX(?paLabel, '^usage', 'i') ||
# REGEX(?paLabel, '^ribavirin', 'i') ||
# REGEX(?paLabel, '^vigorous', 'i') ||
# REGEX(?paLabel, '^neuropathogenesis', 'i') ||
# REGEX(?paLabel, '^pcr', 'i') ||
# REGEX(?paLabel, '^systemic', 'i') ||
# REGEX(?paLabel, '^therapeutic', 'i') ||
# REGEX(?paLabel, '^polycation', 'i') ||
# REGEX(?paLabel, '^virus-specific', 'i') ||
# REGEX(?paLabel, '^cleave', 'i') ||
# REGEX(?paLabel, '^played', 'i') ||
# REGEX(?paLabel, '^pathogenetic', 'i') ||
# REGEX(?paLabel, '^events', 'i') ||
# REGEX(?paLabel, '^ntpase', 'i') ||
# REGEX(?paLabel, '^silico', 'i') ||
# REGEX(?paLabel, '^iga', 'i') ||
# REGEX(?paLabel, '^spillover', 'i') ||
# REGEX(?paLabel, '^mutation', 'i') ||
# REGEX(?paLabel, '^isotype-specific', 'i') ||
# REGEX(?paLabel, '^lds', 'i') ||
# REGEX(?paLabel, '^pathological', 'i') ||
# REGEX(?paLabel, '^predisposition', 'i') ||
# REGEX(?paLabel, '^exogenous', 'i') ||
# REGEX(?paLabel, '^o-linked', 'i') ||
# REGEX(?paLabel, '^induces', 'i') ||
# REGEX(?paLabel, '^trimester', 'i') ||
# REGEX(?paLabel, '^boar', 'i') ||
# REGEX(?paLabel, '^optic', 'i') ||
# REGEX(?paLabel, '^transgenic', 'i') ||
# REGEX(?paLabel, '^reported', 'i') ||
# REGEX(?paLabel, '^passively', 'i') ||
# REGEX(?paLabel, '^climates', 'i') ||
# REGEX(?paLabel, '^recommendations', 'i') ||
# REGEX(?paLabel, '^hydrophilic', 'i') ||
# REGEX(?paLabel, '^homooligomeric', 'i') ||
# REGEX(?paLabel, '^lactation', 'i') ||
# REGEX(?paLabel, '^modification', 'i') ||
# REGEX(?paLabel, '^reasons', 'i') ||
# REGEX(?paLabel, '^downstream', 'i') ||
# REGEX(?paLabel, '^hydrophobicity', 'i') ||
# REGEX(?paLabel, '^neutrophils', 'i') ||
# REGEX(?paLabel, '^earlier', 'i') ||
# REGEX(?paLabel, '^scenarios', 'i') ||
# REGEX(?paLabel, '^fidelity', 'i') ||
# REGEX(?paLabel, '^differentiation', 'i') ||
# REGEX(?paLabel, '^convincing', 'i') ||
# REGEX(?paLabel, '^angiotensin-converting', 'i') ||
# REGEX(?paLabel, '^rotavirus', 'i') ||
# REGEX(?paLabel, '^interventions', 'i') ||
# REGEX(?paLabel, '^defects', 'i') ||
# REGEX(?paLabel, '^coagulation', 'i') ||
# REGEX(?paLabel, '^prototype', 'i') ||
# REGEX(?paLabel, '^membranous', 'i') ||
# REGEX(?paLabel, '^novirhabdovirus', 'i') ||
# REGEX(?paLabel, '^distances', 'i') ||
# REGEX(?paLabel, '^replication', 'i') ||
# REGEX(?paLabel, '^icam-grabbing', 'i') ||
# REGEX(?paLabel, '^cut-off', 'i') ||
# REGEX(?paLabel, '^comparative', 'i') ||
# REGEX(?paLabel, '^effectors', 'i') ||
# REGEX(?paLabel, '^zoonotic', 'i') ||
# REGEX(?paLabel, '^odn', 'i') ||
# REGEX(?paLabel, '^arbovirus', 'i') ||
# REGEX(?paLabel, '^sendai', 'i') ||
# REGEX(?paLabel, '^co-pathogens', 'i') ||
# REGEX(?paLabel, '^circovirus', 'i') ||
# REGEX(?paLabel, '^peptide', 'i') ||
# REGEX(?paLabel, '^felis', 'i') ||
# REGEX(?paLabel, '^ascoviruses', 'i') ||
# REGEX(?paLabel, '^sarcoma', 'i') ||
# REGEX(?paLabel, '^visualization', 'i') ||
# REGEX(?paLabel, '^doses', 'i') ||
# REGEX(?paLabel, '^phytoestrogen', 'i') ||
# REGEX(?paLabel, '^nonlinear', 'i') ||
# REGEX(?paLabel, '^distributions', 'i') ||
# REGEX(?paLabel, '^abortus', 'i') ||
# REGEX(?paLabel, '^structure-based', 'i') ||
# REGEX(?paLabel, '^microbiome', 'i') ||
# REGEX(?paLabel, '^circulation', 'i') ||
# REGEX(?paLabel, '^unifying', 'i') ||
# REGEX(?paLabel, '^antecedents', 'i') ||
# REGEX(?paLabel, '^proteome-wide', 'i') ||
# REGEX(?paLabel, '^dictates', 'i') ||
# REGEX(?paLabel, '^mosquito', 'i') ||
# REGEX(?paLabel, '^rodents', 'i') ||
# REGEX(?paLabel, '^hospitalized', 'i') ||
# REGEX(?paLabel, '^complementary', 'i') ||
# REGEX(?paLabel, '^parameters', 'i') ||
# REGEX(?paLabel, '^abnormalities', 'i') ||
# REGEX(?paLabel, '^reovirus', 'i') ||
# REGEX(?paLabel, '^cocktail', 'i') ||
# REGEX(?paLabel, '^nonfunctional', 'i') ||
# REGEX(?paLabel, '^cynomolgus', 'i') ||
# REGEX(?paLabel, '^oligoclonal', 'i') ||
# REGEX(?paLabel, '^samples', 'i') ||
# REGEX(?paLabel, '^metacommunity', 'i') ||
# REGEX(?paLabel, '^rodent', 'i') ||
# REGEX(?paLabel, '^neuronal', 'i') ||
# REGEX(?paLabel, '^nucleolus', 'i') ||
# REGEX(?paLabel, '^c-type', 'i') ||
# REGEX(?paLabel, '^alpha', 'i') ||
# REGEX(?paLabel, '^env', 'i') ||
# REGEX(?paLabel, '^ancestral', 'i') ||
# REGEX(?paLabel, '^octapeptide', 'i') ||
# REGEX(?paLabel, '^tgev', 'i') ||
# REGEX(?paLabel, '^cfp', 'i') ||
# REGEX(?paLabel, '^impairment', 'i') ||
# REGEX(?paLabel, '^insufficient', 'i') ||
# REGEX(?paLabel, '^case-control', 'i') ||
# REGEX(?paLabel, '^rhinolophidae', 'i') ||
# REGEX(?paLabel, '^intricate', 'i') ||
# REGEX(?paLabel, '^rnc', 'i') ||
# REGEX(?paLabel, '^erythrocyte', 'i') ||
# REGEX(?paLabel, '^pedv-positive', 'i') ||
# REGEX(?paLabel, '^sitewise', 'i') ||
# REGEX(?paLabel, '^repeated', 'i') ||
# REGEX(?paLabel, '^hfold', 'i') ||
# REGEX(?paLabel, '^households', 'i') ||
# REGEX(?paLabel, '^areas', 'i') ||
# REGEX(?paLabel, '^colon', 'i') ||
# REGEX(?paLabel, '^bats', 'i') ||
# REGEX(?paLabel, '^bnabs', 'i') ||
# REGEX(?paLabel, '^hyaluronan', 'i') ||
# REGEX(?paLabel, '^points', 'i') ||
# REGEX(?paLabel, '^opportunities', 'i') ||
# REGEX(?paLabel, '^pubmed', 'i') ||
# REGEX(?paLabel, '^a-allele', 'i') ||
# REGEX(?paLabel, '^grounds', 'i') ||
# REGEX(?paLabel, '^breeding', 'i') ||
# REGEX(?paLabel, '^unravel', 'i') ||
# REGEX(?paLabel, '^viral-induced', 'i') ||
# REGEX(?paLabel, '^n-calls', 'i') ||
# REGEX(?paLabel, '^sulfate', 'i') ||
# REGEX(?paLabel, '^reassortant', 'i') ||
# REGEX(?paLabel, '^inbreeding', 'i') ||
# REGEX(?paLabel, '^mscs', 'i') ||
# REGEX(?paLabel, '^preganglionic', 'i') ||
# REGEX(?paLabel, '^postmortem', 'i') ||
# REGEX(?paLabel, '^pseudogene', 'i') ||
# REGEX(?paLabel, '^advances', 'i') ||
# REGEX(?paLabel, '^suprabasal', 'i') ||
# REGEX(?paLabel, '^mechanisms', 'i') ||
# REGEX(?paLabel, '^comparisons', 'i') ||
# REGEX(?paLabel, '^influenza', 'i') ||
# REGEX(?paLabel, '^presenting', 'i') ||
# REGEX(?paLabel, '^injured', 'i') ||
# REGEX(?paLabel, '^models', 'i') ||
# REGEX(?paLabel, '^cineole', 'i') ||
# REGEX(?paLabel, '^alv-j', 'i') ||
# REGEX(?paLabel, '^perforation', 'i') ||
# REGEX(?paLabel, '^arvicola', 'i') ||
# REGEX(?paLabel, '^anti-inflammatory', 'i') ||
# REGEX(?paLabel, '^hydrolysis', 'i') ||
# REGEX(?paLabel, '^unicellular', 'i') ||
# REGEX(?paLabel, '^superstitious', 'i') ||
# REGEX(?paLabel, '^updates', 'i') ||
# REGEX(?paLabel, '^signals', 'i') ||
# REGEX(?paLabel, '^mers-cov', 'i') ||
# REGEX(?paLabel, '^plethora', 'i') ||
# REGEX(?paLabel, '^animals', 'i') ||
# REGEX(?paLabel, '^eukaryotic', 'i') ||
# REGEX(?paLabel, '^truncated', 'i') ||
# REGEX(?paLabel, '^csax', 'i') ||
# REGEX(?paLabel, '^interactions', 'i') ||
# REGEX(?paLabel, '^hp-prrsv', 'i') ||
# REGEX(?paLabel, '^compounds', 'i') ||
# REGEX(?paLabel, '^mathematical', 'i') ||
# REGEX(?paLabel, '^retinoic', 'i') ||
# REGEX(?paLabel, '^vaccines', 'i') ||
# REGEX(?paLabel, '^somatic', 'i') ||
# REGEX(?paLabel, '^allergic', 'i') ||
# REGEX(?paLabel, '^feline', 'i') ||
# REGEX(?paLabel, '^children', 'i') ||
# REGEX(?paLabel, '^pdcs', 'i') ||
# REGEX(?paLabel, '^damps', 'i') ||
# REGEX(?paLabel, '^speculations', 'i') ||
# REGEX(?paLabel, '^stem-like', 'i') ||
# REGEX(?paLabel, '^immunologic', 'i') ||
# REGEX(?paLabel, '^fasl', 'i') ||
# REGEX(?paLabel, '^lt-mediated', 'i') ||
# REGEX(?paLabel, '^host-supplied', 'i') ||
# REGEX(?paLabel, '^lineage', 'i') ||
# REGEX(?paLabel, '^semi-quantitative', 'i') ||
# REGEX(?paLabel, '^estimates', 'i') ||
# REGEX(?paLabel, '^ibdv', 'i') ||
# REGEX(?paLabel, '^antibodies', 'i') ||
# REGEX(?paLabel, '^channels', 'i') ||
# REGEX(?paLabel, '^compromises', 'i') ||
# REGEX(?paLabel, '^topical', 'i') ||
# REGEX(?paLabel, '^complement', 'i') ||
# REGEX(?paLabel, '^mers-covs', 'i') ||
# REGEX(?paLabel, '^gestational', 'i') ||
# REGEX(?paLabel, '^structures', 'i') ||
# REGEX(?paLabel, '^kinetic', 'i') ||
# REGEX(?paLabel, '^dietary', 'i') ||
# REGEX(?paLabel, '^ad-like', 'i') ||
# REGEX(?paLabel, '^rti', 'i') ||
# REGEX(?paLabel, '^reactive', 'i') ||
# REGEX(?paLabel, '^apoptosis', 'i') ||
# REGEX(?paLabel, '^quantitative', 'i') ||
# REGEX(?paLabel, '^stimulating', 'i') ||
# REGEX(?paLabel, '^alternate', 'i') ||
# REGEX(?paLabel, '^ph-dependent', 'i') ||
# REGEX(?paLabel, '^harvis', 'i') ||
# REGEX(?paLabel, '^sfts', 'i') ||
# REGEX(?paLabel, '^homogeneity', 'i') ||
# REGEX(?paLabel, '^bacterial-host', 'i') ||
# REGEX(?paLabel, '^lions', 'i') ||
# REGEX(?paLabel, '^glycan', 'i') ||
# REGEX(?paLabel, '^mutants', 'i') ||
# REGEX(?paLabel, '^diversified', 'i') ||
# REGEX(?paLabel, '^mononuclear', 'i') ||
# REGEX(?paLabel, '^transcripts', 'i') ||
# REGEX(?paLabel, '^maternal-fetal', 'i') ||
# REGEX(?paLabel, '^antecedent', 'i') ||
# REGEX(?paLabel, '^neutrophil', 'i') ||
# REGEX(?paLabel, '^matches', 'i') ||
# REGEX(?paLabel, '^ichnoviruses', 'i') ||
# REGEX(?paLabel, '^toll-like', 'i') ||
# REGEX(?paLabel, '^mycobacterial', 'i') ||
# REGEX(?paLabel, '^adaptations', 'i') ||
# REGEX(?paLabel, '^iprot-sub', 'i') ||
# REGEX(?paLabel, '^hepadnaviruses', 'i') ||
# REGEX(?paLabel, '^cats', 'i') ||
# REGEX(?paLabel, '^myotis', 'i') ||
# REGEX(?paLabel, '^analog', 'i') ||
# REGEX(?paLabel, '^coli', 'i') ||
# REGEX(?paLabel, '^oligomer', 'i') ||
# REGEX(?paLabel, '^stratification', 'i') ||
# REGEX(?paLabel, '^trajectory', 'i') ||
# REGEX(?paLabel, '^sialic', 'i') ||
# REGEX(?paLabel, '^clones', 'i') ||
# REGEX(?paLabel, '^mutagenic', 'i') ||
# REGEX(?paLabel, '^approaches', 'i') ||
# REGEX(?paLabel, '^sepsis', 'i') ||
# REGEX(?paLabel, '^uses', 'i') ||
# REGEX(?paLabel, '^microbial', 'i') ||
# REGEX(?paLabel, '^sars-cov', 'i') ||
# REGEX(?paLabel, '^stresses', 'i') ||
# REGEX(?paLabel, '^enveloped', 'i') ||
# REGEX(?paLabel, '^bees', 'i') ||
# REGEX(?paLabel, '^dendritic', 'i') ||
# REGEX(?paLabel, '^hyenas', 'i') ||
# REGEX(?paLabel, '^peacock', 'i') ||
# REGEX(?paLabel, '^destabilizing', 'i') ||
# REGEX(?paLabel, '^ipa', 'i') ||
# REGEX(?paLabel, '^self-destruct', 'i') ||
# REGEX(?paLabel, '^vagal', 'i') ||
# REGEX(?paLabel, '^phagocytotic', 'i') ||
# REGEX(?paLabel, '^cytoplasm', 'i') ||
# REGEX(?paLabel, '^commensals', 'i') ||
# REGEX(?paLabel, '^prevailing', 'i') ||
# REGEX(?paLabel, '^fvhh', 'i') ||
# REGEX(?paLabel, '^respirable', 'i') ||
# REGEX(?paLabel, '^ecology', 'i') ||
# REGEX(?paLabel, '^capsid', 'i') ||
# REGEX(?paLabel, '^internalization', 'i') ||
# REGEX(?paLabel, '^livestock', 'i') ||
# REGEX(?paLabel, '^namely', 'i') ||
# REGEX(?paLabel, '^localization', 'i') ||
# REGEX(?paLabel, '^randomized', 'i') ||
# REGEX(?paLabel, '^radiotherapy', 'i') ||
# REGEX(?paLabel, '^residue', 'i') ||
# REGEX(?paLabel, '^conformational', 'i') ||
# REGEX(?paLabel, '^parallels', 'i') ||
# REGEX(?paLabel, '^instrumental', 'i') ||
# REGEX(?paLabel, '^acid-dependent', 'i') ||
# REGEX(?paLabel, '^hitchhiker', 'i') ||
# REGEX(?paLabel, '^murine', 'i') ||
# REGEX(?paLabel, '^interstitial', 'i') ||
# REGEX(?paLabel, '^broad-spectrum', 'i') ||
# REGEX(?paLabel, '^myeloperoxidase', 'i') ||
# REGEX(?paLabel, '^epigenome', 'i') ||
# REGEX(?paLabel, '^high-fidelity', 'i') ||
# REGEX(?paLabel, '^incidental', 'i') ||
# REGEX(?paLabel, '^immunity', 'i') ||
# REGEX(?paLabel, '^dominant-negative', 'i') ||
# REGEX(?paLabel, '^pharmacodynamics', 'i') ||
# REGEX(?paLabel, '^clearance', 'i') ||
# REGEX(?paLabel, '^canada', 'i') ||
# REGEX(?paLabel, '^offspring', 'i') ||
# REGEX(?paLabel, '^one-child', 'i') ||
# REGEX(?paLabel, '^diseases', 'i') ||
# REGEX(?paLabel, '^deposition', 'i') ||
# REGEX(?paLabel, '^workers', 'i') ||
# REGEX(?paLabel, '^liposome-based', 'i') ||
# REGEX(?paLabel, '^subunit', 'i') ||
# REGEX(?paLabel, '^africa', 'i') ||
# REGEX(?paLabel, '^migratory', 'i') ||
# REGEX(?paLabel, '^bioaerosols', 'i') ||
# REGEX(?paLabel, '^morphogenesis', 'i') ||
# REGEX(?paLabel, '^larger', 'i') ||
# REGEX(?paLabel, '^diagnoses', 'i') ||
# REGEX(?paLabel, '^insertions', 'i') ||
# REGEX(?paLabel, '^virus-cell', 'i') ||
# REGEX(?paLabel, '^circulates', 'i') ||
# REGEX(?paLabel, '^ifn-i', 'i') ||
# REGEX(?paLabel, '^resides', 'i') ||
# REGEX(?paLabel, '^ards', 'i') ||
# REGEX(?paLabel, '^behaviour', 'i') ||
# REGEX(?paLabel, '^humoral', 'i') ||
# REGEX(?paLabel, '^arbitrary', 'i') ||
# REGEX(?paLabel, '^dsc', 'i') ||
# REGEX(?paLabel, '^mitochondria', 'i') ||
# REGEX(?paLabel, '^autoantigens', 'i') ||
# REGEX(?paLabel, '^fmdv', 'i') ||
# REGEX(?paLabel, '^egfr', 'i') ||
# REGEX(?paLabel, '^trachea', 'i') ||
# REGEX(?paLabel, '^high-', 'i') ||
# REGEX(?paLabel, '^differentiated', 'i') ||
# REGEX(?paLabel, '^repeats', 'i') ||
# REGEX(?paLabel, '^testable', 'i') ||
# REGEX(?paLabel, '^nidovirus', 'i') ||
# REGEX(?paLabel, '^reactivity', 'i') ||
# REGEX(?paLabel, '^hygiene', 'i') ||
# REGEX(?paLabel, '^computational', 'i') ||
# REGEX(?paLabel, '^scores', 'i') ||
# REGEX(?paLabel, '^drugs', 'i') ||
# REGEX(?paLabel, '^surfaces', 'i') ||
# REGEX(?paLabel, '^china', 'i') ||
# REGEX(?paLabel, '^herpesvirus', 'i') ||
# REGEX(?paLabel, '^degradation', 'i') ||
# REGEX(?paLabel, '^pathogen-targeting', 'i') ||
# REGEX(?paLabel, '^imbalances', 'i') ||
# REGEX(?paLabel, '^hbsag', 'i') ||
# REGEX(?paLabel, '^atherosclerosis', 'i') ||
# REGEX(?paLabel, '^ventilator', 'i') ||
# REGEX(?paLabel, '^plaque', 'i') ||
# REGEX(?paLabel, '^matrigel', 'i') ||
# REGEX(?paLabel, '^hamilton', 'i') ||
# REGEX(?paLabel, '^clusters', 'i') ||
# REGEX(?paLabel, '^heightened', 'i') ||
# REGEX(?paLabel, '^generalizations', 'i') ||
# REGEX(?paLabel, '^authors', 'i') ||
# REGEX(?paLabel, '^nidoviruses', 'i') ||
# REGEX(?paLabel, '^inactive', 'i') ||
# REGEX(?paLabel, '^phenotype', 'i') ||
# REGEX(?paLabel, '^golgi', 'i') ||
# REGEX(?paLabel, '^subsets', 'i') ||
# REGEX(?paLabel, '^clues', 'i') ||
# REGEX(?paLabel, '^transcription', 'i') ||
# REGEX(?paLabel, '^america', 'i') ||
# REGEX(?paLabel, '^codon', 'i') ||
# REGEX(?paLabel, '^ace', 'i') ||
# REGEX(?paLabel, '^entities', 'i') ||
# REGEX(?paLabel, '^ascovirus', 'i') ||
# REGEX(?paLabel, '^causative', 'i') ||
# REGEX(?paLabel, '^ras', 'i') ||
# REGEX(?paLabel, '^mutated', 'i') ||
# REGEX(?paLabel, '^fplv', 'i') ||
# REGEX(?paLabel, '^ppe', 'i') ||
# REGEX(?paLabel, '^biodegradable', 'i') ||
# REGEX(?paLabel, '^persons', 'i') ||
# REGEX(?paLabel, '^subjects', 'i') ||
# REGEX(?paLabel, '^artery', 'i') ||
# REGEX(?paLabel, '^places', 'i') ||
# REGEX(?paLabel, '^predelivery', 'i') ||
# REGEX(?paLabel, '^specialized', 'i') ||
# REGEX(?paLabel, '^lectins', 'i') ||
# REGEX(?paLabel, '^ros', 'i') ||
# REGEX(?paLabel, '^packaging', 'i') ||
# REGEX(?paLabel, '^cyclin', 'i') ||
# REGEX(?paLabel, '^migrations', 'i') ||
# REGEX(?paLabel, '^variables', 'i') ||
# REGEX(?paLabel, '^lesions', 'i') ||
# REGEX(?paLabel, '^hesperidus', 'i') ||
# REGEX(?paLabel, '^pbmcs', 'i') ||
# REGEX(?paLabel, '^tuberculosis', 'i') ||
# REGEX(?paLabel, '^investigations', 'i') ||
# REGEX(?paLabel, '^efferent', 'i') ||
# REGEX(?paLabel, '^robust', 'i') ||
# REGEX(?paLabel, '^genbank', 'i') ||
# REGEX(?paLabel, '^susceptible', 'i') ||
# REGEX(?paLabel, '^mbl', 'i') ||
# REGEX(?paLabel, '^peninsula', 'i') ||
# REGEX(?paLabel, '^antigenicity', 'i') ||
# REGEX(?paLabel, '^eukaryote', 'i') ||
# REGEX(?paLabel, '^frequencies', 'i') ||
# REGEX(?paLabel, '^handle-cleaning', 'i') ||
# REGEX(?paLabel, '^soluble', 'i') ||
# REGEX(?paLabel, '^wisconsin', 'i') ||
# REGEX(?paLabel, '^thresholds', 'i') ||
# REGEX(?paLabel, '^regimen', 'i') ||
# REGEX(?paLabel, '^kong', 'i') ||
# REGEX(?paLabel, '^ligand', 'i') ||
# REGEX(?paLabel, '^allergen', 'i') ||
# REGEX(?paLabel, '^concentrations', 'i') ||
# REGEX(?paLabel, '^coherent', 'i') ||
# REGEX(?paLabel, '^leptospira-infection', 'i') ||
# ...
# REGEX(?paLabel, '^transduction', 'i') ||
# REGEX(?paLabel, '^temperate', 'i') ||
# REGEX(?paLabel, '^activation', 'i') ||
# REGEX(?paLabel, '^autosensitization', 'i') ||
# REGEX(?paLabel, '^wild-type', 'i') ||
# REGEX(?paLabel, '^primitive', 'i') ||
# REGEX(?paLabel, '^t-cell', 'i') ||
# REGEX(?paLabel, '^aberrant', 'i') ||
# REGEX(?paLabel, '^ribosome-mediated', 'i') ||
# REGEX(?paLabel, '^bleomycin', 'i') ||
# REGEX(?paLabel, '^detection', 'i') ||
# REGEX(?paLabel, '^breakdown', 'i') ||
# REGEX(?paLabel, '^chains', 'i') ||
# REGEX(?paLabel, '^rna-dependent', 'i') ||
# REGEX(?paLabel, '^rostral', 'i') ||
# REGEX(?paLabel, '^homologs', 'i') ||
# REGEX(?paLabel, '^immaturity', 'i') ||
# REGEX(?paLabel, '^properties', 'i') ||
# REGEX(?paLabel, '^virological', 'i') ||
# REGEX(?paLabel, '^defective', 'i') ||
# REGEX(?paLabel, '^etiopathogenesis', 'i') ||
# REGEX(?paLabel, '^cub', 'i') ||
# REGEX(?paLabel, '^activated', 'i') ||
# REGEX(?paLabel, '^nutrients', 'i') ||
# REGEX(?paLabel, '^tropism', 'i') ||
# REGEX(?paLabel, '^locations', 'i') ||
# REGEX(?paLabel, '^phylogeographic', 'i') ||
# REGEX(?paLabel, '^hotknots', 'i') ||
# REGEX(?paLabel, '^ino', 'i') ||
# REGEX(?paLabel, '^pathways', 'i') ||
# REGEX(?paLabel, '^secreted', 'i') ||
# REGEX(?paLabel, '^stss', 'i') ||
# REGEX(?paLabel, '^temporal', 'i') ||
# REGEX(?paLabel, '^hyperoxic', 'i') ||
# REGEX(?paLabel, '^responses', 'i') ||
# REGEX(?paLabel, '^abc-type', 'i') ||
# REGEX(?paLabel, '^fss', 'i') ||
# REGEX(?paLabel, '^folding', 'i') ||
# REGEX(?paLabel, '^precursor', 'i') ||
# REGEX(?paLabel, '^germline', 'i') ||
# REGEX(?paLabel, '^drips', 'i') ||
# REGEX(?paLabel, '^students', 'i') ||
# REGEX(?paLabel, '^hypothesis-generating', 'i') ||
# REGEX(?paLabel, '^prespecified', 'i') ||
# REGEX(?paLabel, '^receptor', 'i') ||
# REGEX(?paLabel, '^hcv', 'i') ||
# REGEX(?paLabel, '^microparasites', 'i') ||
# REGEX(?paLabel, '^mps', 'i') ||
# REGEX(?paLabel, '^bibliography', 'i') ||
# REGEX(?paLabel, '^populationgenetic', 'i') ||
# REGEX(?paLabel, '^relationships', 'i') ||
# REGEX(?paLabel, '^dysfunction', 'i') ||
# REGEX(?paLabel, '^antibiotic', 'i') ||
# REGEX(?paLabel, '^copd', 'i') ||
# REGEX(?paLabel, '^upstream', 'i') ||
# REGEX(?paLabel, '^intervals', 'i') ||
# REGEX(?paLabel, '^reservoir', 'i') ||
# REGEX(?paLabel, '^inflammatory', 'i') ||
# REGEX(?paLabel, '^receptors', 'i') ||
# REGEX(?paLabel, '^shaping', 'i') ||
# REGEX(?paLabel, '^trimeric', 'i') ||
# REGEX(?paLabel, '^segments', 'i') ||
# REGEX(?paLabel, '^substances', 'i') ||
# REGEX(?paLabel, '^periodontitis', 'i') ||
# REGEX(?paLabel, '^generating', 'i') ||
# REGEX(?paLabel, '^introduced', 'i') ||
# REGEX(?paLabel, '^glomerulonephritis', 'i') ||
# REGEX(?paLabel, '^damp', 'i') ||
# REGEX(?paLabel, '^balf', 'i') ||
# REGEX(?paLabel, '^vpu', 'i') ||
# REGEX(?paLabel, '^polymerase', 'i') ||
# REGEX(?paLabel, '^tcbat', 'i') ||
# REGEX(?paLabel, '^optimal', 'i') ||
# REGEX(?paLabel, '^chronically', 'i') ||
# REGEX(?paLabel, '^saliva', 'i') ||
# REGEX(?paLabel, '^bronchial', 'i') ||
# REGEX(?paLabel, '^vitro', 'i') ||
# REGEX(?paLabel, '^types', 'i') ||
# REGEX(?paLabel, '^targeting', 'i') ||
# REGEX(?paLabel, '^numbers', 'i') ||
# REGEX(?paLabel, '^infected', 'i') ||
# REGEX(?paLabel, '^rv-c', 'i') ||
# REGEX(?paLabel, '^dysregulation', 'i') ||
# REGEX(?paLabel, '^senescence', 'i') ||
# REGEX(?paLabel, '^intracellular', 'i') ||
# REGEX(?paLabel, '^co-infections', 'i') ||
# REGEX(?paLabel, '^notch', 'i') ||
# REGEX(?paLabel, '^vaccine', 'i') ||
# REGEX(?paLabel, '^scoping', 'i') ||
# REGEX(?paLabel, '^cyclosporine', 'i') ||
# REGEX(?paLabel, '^supporting', 'i') ||
# REGEX(?paLabel, '^synthetic', 'i') ||
# REGEX(?paLabel, '^histiocytic', 'i') ||
# REGEX(?paLabel, '^resources', 'i') ||
# REGEX(?paLabel, '^virus-induced', 'i') ||
# REGEX(?paLabel, '^compartments', 'i') ||
# REGEX(?paLabel, '^sources', 'i') ||
# REGEX(?paLabel, '^polyubiquitin', 'i') ||
# REGEX(?paLabel, '^degradasome', 'i') ||
# REGEX(?paLabel, '^interrogation', 'i') ||
# REGEX(?paLabel, '^circumstances', 'i') ||
# REGEX(?paLabel, '^serms', 'i') ||
# REGEX(?paLabel, '^phenotypic', 'i') ||
# REGEX(?paLabel, '^double-positive', 'i') ||
# REGEX(?paLabel, '^pa-x', 'i') ||
# REGEX(?paLabel, '^transplant', 'i') ||
# REGEX(?paLabel, '^biogeographical', 'i') ||
# REGEX(?paLabel, '^ebola', 'i') ||
# REGEX(?paLabel, '^inclusion', 'i') ||
# REGEX(?paLabel, '^initiating', 'i') ||
# REGEX(?paLabel, '^hypothalamus', 'i') ||
# REGEX(?paLabel, '^airway-related', 'i') ||
# REGEX(?paLabel, '^treatments', 'i') ||
# REGEX(?paLabel, '^pten', 'i') ||
# REGEX(?paLabel, '^animal', 'i') ||
# REGEX(?paLabel, '^pdc', 'i') ||
# REGEX(?paLabel, '^granule', 'i') ||
# REGEX(?paLabel, '^investigators', 'i') ||
# REGEX(?paLabel, '^nab', 'i') ||
# REGEX(?paLabel, '^anatomical', 'i') ||
# REGEX(?paLabel, '^coronary', 'i') ||
# REGEX(?paLabel, '^mice', 'i') ||
# REGEX(?paLabel, '^replicative', 'i') ||
# REGEX(?paLabel, '^fluids', 'i') ||
# REGEX(?paLabel, '^dc-signr', 'i') ||
# REGEX(?paLabel, '^non-infected', 'i') ||
# REGEX(?paLabel, '^homeostasis', 'i') ||
# REGEX(?paLabel, '^non-spatial', 'i') ||
# REGEX(?paLabel, '^aggregation', 'i') ||
# REGEX(?paLabel, '^conserved', 'i') ||
# REGEX(?paLabel, '^dynamin-', 'i') ||
# REGEX(?paLabel, '^duplications', 'i') ||
# REGEX(?paLabel, '^technologies', 'i') ||
# REGEX(?paLabel, '^illnesses', 'i') ||
# REGEX(?paLabel, '^hbv', 'i') ||
# REGEX(?paLabel, '^self-epitopes', 'i') ||
# REGEX(?paLabel, '^haplotypes', 'i') ||
# REGEX(?paLabel, '^pharmacokinetics', 'i') ||
# REGEX(?paLabel, '^interfaces', 'i') ||
# REGEX(?paLabel, '^pre-existing', 'i') ||
# REGEX(?paLabel, '^lactogenic', 'i') ||
# REGEX(?paLabel, '^ph-', 'i') ||
# REGEX(?paLabel, '^teff', 'i') ||
# REGEX(?paLabel, '^particles', 'i') ||
# REGEX(?paLabel, '^charged', 'i') ||
# REGEX(?paLabel, '^reactions', 'i') ||
# REGEX(?paLabel, '^products', 'i') ||
# REGEX(?paLabel, '^mastitis', 'i') ||
# REGEX(?paLabel, '^btb', 'i') ||
# REGEX(?paLabel, '^selective', 'i') ||
# REGEX(?paLabel, '^inbuilt', 'i') ||
# REGEX(?paLabel, '^b-cells', 'i') ||
# REGEX(?paLabel, '^principles', 'i') ||
# REGEX(?paLabel, '^milrnas', 'i') ||
# REGEX(?paLabel, '^dc-sign', 'i') ||
# REGEX(?paLabel, '^endosomes', 'i') ||
# REGEX(?paLabel, '^chlamydia', 'i') ||
# REGEX(?paLabel, '^protease-specific', 'i') ||
# REGEX(?paLabel, '^elevated', 'i') ||
# REGEX(?paLabel, '^post-translational', 'i') ||
# REGEX(?paLabel, '^ovine', 'i') ||
# REGEX(?paLabel, '^peritonitis', 'i') ||
# REGEX(?paLabel, '^complications', 'i') ||
# REGEX(?paLabel, '^two-child', 'i') ||
# REGEX(?paLabel, '^ibv', 'i') ||
# REGEX(?paLabel, '^introductions', 'i') ||
# REGEX(?paLabel, '^residents', 'i') ||
# REGEX(?paLabel, '^associations', 'i') ||
# REGEX(?paLabel, '^budding', 'i') ||
# REGEX(?paLabel, '^compensatory', 'i') ||
# REGEX(?paLabel, '^prone', 'i') ||
# REGEX(?paLabel, '^hosts', 'i') ||
# REGEX(?paLabel, '^droplets', 'i') ||
# REGEX(?paLabel, '^electricity-free', 'i') ||
# REGEX(?paLabel, '^gags', 'i') ||
# REGEX(?paLabel, '^bloodmeals', 'i') ||
# REGEX(?paLabel, '^participants', 'i') ||
# REGEX(?paLabel, '^standardised', 'i') ||
# REGEX(?paLabel, '^pbv', 'i') ||
# REGEX(?paLabel, '^lgg', 'i') ||
# REGEX(?paLabel, '^toxicity', 'i') ||
# REGEX(?paLabel, '^dispositional', 'i') ||
# REGEX(?paLabel, '^polymorphism', 'i') ||
# REGEX(?paLabel, '^coupling', 'i') ||
# REGEX(?paLabel, '^deftp', 'i') ||
# REGEX(?paLabel, '^reduced', 'i') ||
# REGEX(?paLabel, '^ictv', 'i') ||
# REGEX(?paLabel, '^catus', 'i') ||
# REGEX(?paLabel, '^cics', 'i') ||
# REGEX(?paLabel, '^alteration', 'i') ||
# REGEX(?paLabel, '^cholera', 'i') ||
# REGEX(?paLabel, '^bronchoalveolar', 'i') ||
# REGEX(?paLabel, '^systems', 'i') ||
# REGEX(?paLabel, '^aidpogenesis', 'i') ||
# REGEX(?paLabel, '^factor', 'i') ||
# REGEX(?paLabel, '^inducible', 'i') ||
# REGEX(?paLabel, '^keratinocytes', 'i') ||
# REGEX(?paLabel, '^insensitivity', 'i') ||
# REGEX(?paLabel, '^substrates', 'i') ||
# REGEX(?paLabel, '^predictions', 'i') ||
# REGEX(?paLabel, '^susceptibility', 'i') ||
# REGEX(?paLabel, '^sarcoidosis', 'i') ||
# REGEX(?paLabel, '^microenvironment', 'i') ||
# REGEX(?paLabel, '^nested', 'i') ||
# REGEX(?paLabel, '^linkages', 'i') ||
# REGEX(?paLabel, '^ducks', 'i') ||
# REGEX(?paLabel, '^exosomes', 'i') ||
# REGEX(?paLabel, '^orthohepevirus', 'i') ||
# REGEX(?paLabel, '^ppi', 'i') ||
# REGEX(?paLabel, '^combinatorial', 'i') ||
# REGEX(?paLabel, '^degrees', 'i') ||
# REGEX(?paLabel, '^primates', 'i') ||
# REGEX(?paLabel, '^immunodeficient', 'i') ||
# REGEX(?paLabel, '^laryngoscope', 'i') ||
# REGEX(?paLabel, '^hantavirus', 'i') ||
# REGEX(?paLabel, '^hipposideridae', 'i') ||
# REGEX(?paLabel, '^hsct', 'i') ||
# REGEX(?paLabel, '^virology', 'i') ||
# REGEX(?paLabel, '^immunogenicity', 'i') ||
# REGEX(?paLabel, '^intrinsic', 'i') ||
# REGEX(?paLabel, '^inheritance', 'i') ||
# REGEX(?paLabel, '^lymphatic', 'i') ||
# REGEX(?paLabel, '^mtb', 'i') ||
# REGEX(?paLabel, '^corticosteroids', 'i') ||
# REGEX(?paLabel, '^brsv', 'i') ||
# REGEX(?paLabel, '^context-dependent', 'i') ||
# REGEX(?paLabel, '^habitats', 'i') ||
# REGEX(?paLabel, '^effects', 'i') ||
# REGEX(?paLabel, '^epitopes', 'i') ||
# REGEX(?paLabel, '^severity', 'i') ||
# REGEX(?paLabel, '^vagina', 'i') ||
# REGEX(?paLabel, '^titers', 'i') ||
# REGEX(?paLabel, '^hrv', 'i') ||
# REGEX(?paLabel, '^iav', 'i') ||
# REGEX(?paLabel, '^marneffei', 'i') ||
# REGEX(?paLabel, '^surviving', 'i') ||
# REGEX(?paLabel, '^hypermutations', 'i') ||
# REGEX(?paLabel, '^chinese', 'i') ||
# REGEX(?paLabel, '^settings', 'i') ||
# REGEX(?paLabel, '^reservoirs', 'i') ||
# REGEX(?paLabel, '^parameter', 'i') ||
# REGEX(?paLabel, '^experience-dependent', 'i') ||
# REGEX(?paLabel, '^commensal', 'i') ||
# REGEX(?paLabel, '^ndna', 'i') ||
# REGEX(?paLabel, '^cns', 'i') ||
# REGEX(?paLabel, '^adhsp-induced', 'i') ||
# REGEX(?paLabel, '^protein-homeostasis-system', 'i') ||
# REGEX(?paLabel, '^sclerosis', 'i') ||
# REGEX(?paLabel, '^jev', 'i') ||
# REGEX(?paLabel, '^interspecies', 'i') ||
# REGEX(?paLabel, '^sites', 'i') ||
# REGEX(?paLabel, '^musculoskeletal', 'i') ||
# REGEX(?paLabel, '^pneumococcal', 'i') ||
# REGEX(?paLabel, '^airways', 'i') ||
# REGEX(?paLabel, '^genomics', 'i') ||
# REGEX(?paLabel, '^mucosal', 'i') ||
# REGEX(?paLabel, '^mexico', 'i') ||
# REGEX(?paLabel, '^assays', 'i') ||
# REGEX(?paLabel, '^dna', 'i') ||
# REGEX(?paLabel, '^dcs', 'i') ||
# REGEX(?paLabel, '^sensors', 'i') ||
# REGEX(?paLabel, '^idiopathic', 'i') ||
# REGEX(?paLabel, '^macaque', 'i') ||
# REGEX(?paLabel, '^allergen-reactive', 'i') ||
# REGEX(?paLabel, '^filtrate', 'i') ||
# REGEX(?paLabel, '^broadly', 'i') ||
# REGEX(?paLabel, '^coughing', 'i') ||
# REGEX(?paLabel, '^gaaagg', 'i') ||
# REGEX(?paLabel, '^prerequisite', 'i') ||
# REGEX(?paLabel, '^latest', 'i') ||
# REGEX(?paLabel, '^victoria', 'i') ||
# REGEX(?paLabel, '^peripheral', 'i') ||
# REGEX(?paLabel, '^probes', 'i') ||
# REGEX(?paLabel, '^tlr', 'i') ||
# REGEX(?paLabel, '^vectors', 'i') ||
# REGEX(?paLabel, '^sequencing', 'i') ||
# REGEX(?paLabel, '^explanations', 'i') ||
# REGEX(?paLabel, '^criterion', 'i') ||
# REGEX(?paLabel, '^obesity', 'i') ||
# REGEX(?paLabel, '^antiseptics', 'i') ||
# REGEX(?paLabel, '^originates', 'i') ||
# REGEX(?paLabel, '^goswami', 'i') ||
# REGEX(?paLabel, '^nasal', 'i') ||
# REGEX(?paLabel, '^veev', 'i') ||
# REGEX(?paLabel, '^macrophages', 'i') ||
# REGEX(?paLabel, '^pathogenic', 'i') ||
# REGEX(?paLabel, '^stages', 'i') ||
# REGEX(?paLabel, '^allergens', 'i') ||
# REGEX(?paLabel, '^cmt', 'i') ||
# REGEX(?paLabel, '^interface', 'i') ||
# REGEX(?paLabel, '^glycosylation', 'i') ||
# REGEX(?paLabel, '^targets', 'i') ||
# REGEX(?paLabel, '^frontiers', 'i') ||
# REGEX(?paLabel, '^iterative', 'i') ||
# REGEX(?paLabel, '^chlamydial', 'i') ||
# REGEX(?paLabel, '^signatures', 'i') ||
# REGEX(?paLabel, '^nonsteroidal', 'i') ||
# REGEX(?paLabel, '^mapk', 'i') ||
# REGEX(?paLabel, '^koalas', 'i') ||
# REGEX(?paLabel, '^sspe', 'i') ||
# REGEX(?paLabel, '^deregulation', 'i') ||
# REGEX(?paLabel, '^organelles', 'i') ||
# REGEX(?paLabel, '^engineered', 'i') ||
# REGEX(?paLabel, '^phylogenetic', 'i') ||
# REGEX(?paLabel, '^factor-positive', 'i') ||
# REGEX(?paLabel, '^exon', 'i') ||
# REGEX(?paLabel, '^chlamydophila', 'i') ||
# REGEX(?paLabel, '^badger', 'i') ||
# REGEX(?paLabel, '^hsa', 'i') ||
# REGEX(?paLabel, '^measures', 'i') ||
# REGEX(?paLabel, '^switching', 'i') ||
# REGEX(?paLabel, '^characteristics', 'i') ||
# REGEX(?paLabel, '^distress', 'i') ||
# REGEX(?paLabel, '^therapeutics', 'i') ||
# REGEX(?paLabel, '^changes', 'i') ||
# REGEX(?paLabel, '^converting', 'i') ||
# REGEX(?paLabel, '^schizophrenia', 'i') ||
# REGEX(?paLabel, '^somatically', 'i') ||
# REGEX(?paLabel, '^sequential', 'i') ||
# REGEX(?paLabel, '^further', 'i') ||
# REGEX(?paLabel, '^collagen', 'i') ||
# REGEX(?paLabel, '^determinants', 'i') ||
# REGEX(?paLabel, '^scaffold', 'i') ||
# REGEX(?paLabel, '^allele', 'i') ||
# REGEX(?paLabel, '^progenitor', 'i') ||
# REGEX(?paLabel, '^duration', 'i') ||
# REGEX(?paLabel, '^steroid-associated', 'i') ||
# REGEX(?paLabel, '^trajectories', 'i') ||
# REGEX(?paLabel, '^eggshell', 'i') ||
# REGEX(?paLabel, '^self-rescue', 'i') ||
# REGEX(?paLabel, '^stimulation', 'i') ||
# REGEX(?paLabel, '^spacing', 'i') ||
# REGEX(?paLabel, '^hepatitis', 'i') ||
# REGEX(?paLabel, '^fetuses', 'i') ||
# REGEX(?paLabel, '^ocular', 'i') ||
# REGEX(?paLabel, '^features', 'i') ||
# REGEX(?paLabel, '^multiprotein', 'i') ||
# REGEX(?paLabel, '^translational', 'i') ||
# REGEX(?paLabel, '^ischemic', 'i') ||
# REGEX(?paLabel, '^serotype', 'i') ||
# REGEX(?paLabel, '^lymph', 'i') ||
# REGEX(?paLabel, '^protocols', 'i') ||
# REGEX(?paLabel, '^adenocarcinoma', 'i') ||
# REGEX(?paLabel, '^counterparts', 'i') ||
# REGEX(?paLabel, '^paramyxovirinae', 'i') ||
# REGEX(?paLabel, '^grft', 'i') ||
# REGEX(?paLabel, '^ald', 'i') ||
# REGEX(?paLabel, '^morbidity', 'i') ||
# REGEX(?paLabel, '^co-expression', 'i') ||
# REGEX(?paLabel, '^absorption', 'i') ||
# REGEX(?paLabel, '^nursing', 'i') ||
# REGEX(?paLabel, '^bystander', 'i') ||
# REGEX(?paLabel, '^inference', 'i') ||
# REGEX(?paLabel, '^injections', 'i') ||
# REGEX(?paLabel, '^secretions', 'i') ||
# REGEX(?paLabel, '^refutation', 'i') ||
# REGEX(?paLabel, '^putative', 'i') ||
# REGEX(?paLabel, '^dsrnas', 'i') ||
# REGEX(?paLabel, '^virus-negative', 'i') ||
# REGEX(?paLabel, '^lytic', 'i') ||
# REGEX(?paLabel, '^epidemiologists', 'i') ||
# REGEX(?paLabel, '^angiotensin', 'i') ||
# REGEX(?paLabel, '^helminth', 'i') ||
# REGEX(?paLabel, '^typhimurium', 'i') ||
# REGEX(?paLabel, '^elements', 'i') ||
# REGEX(?paLabel, '^hairpins', 'i') ||
# REGEX(?paLabel, '^cell-entry', 'i') ||
# REGEX(?paLabel, '^serine', 'i') ||
# REGEX(?paLabel, '^oxidative', 'i') ||
# REGEX(?paLabel, '^hsv', 'i') ||
# REGEX(?paLabel, '^exposures', 'i') ||
# REGEX(?paLabel, '^porcine', 'i') ||
# REGEX(?paLabel, '^enigmatic', 'i') ||
# REGEX(?paLabel, '^plasticity', 'i') ||
# REGEX(?paLabel, '^erk', 'i') ||
# REGEX(?paLabel, '^shorebirds', 'i') ||
# REGEX(?paLabel, '^unrelated', 'i') ||
# REGEX(?paLabel, '^antigen-containing', 'i') ||
# REGEX(?paLabel, '^fetal', 'i') ||
# REGEX(?paLabel, '^sero-positivity', 'i') ||
# REGEX(?paLabel, '^aetiologies', 'i') ||
# REGEX(?paLabel, '^questions', 'i') ||
# REGEX(?paLabel, '^families', 'i') ||
# REGEX(?paLabel, '^mislocalization', 'i') ||
# REGEX(?paLabel, '^icu', 'i') ||
# REGEX(?paLabel, '^vntr', 'i') ||
# REGEX(?paLabel, '^junctions', 'i') ||
# REGEX(?paLabel, '^processes', 'i') ||
# REGEX(?paLabel, '^coronavirus', 'i') ||
# REGEX(?paLabel, '^radiography', 'i') ||
# REGEX(?paLabel, '^ubiquitination', 'i') ||
# REGEX(?paLabel, '^mev', 'i') ||
# REGEX(?paLabel, '^anthropogenic', 'i') ||
# REGEX(?paLabel, '^annealing', 'i') ||
# REGEX(?paLabel, '^viability', 'i') ||
# REGEX(?paLabel, '^australian', 'i') ||
# REGEX(?paLabel, '^rsv-infected', 'i') ||
# REGEX(?paLabel, '^molecular', 'i') ||
# REGEX(?paLabel, '^ben', 'i') ||
# REGEX(?paLabel, '^cortex', 'i') ||
# REGEX(?paLabel, '^mammalian', 'i') ||
# REGEX(?paLabel, '^mapping', 'i') ||
# REGEX(?paLabel, '^vertebrate', 'i') ||
# REGEX(?paLabel, '^calf', 'i') ||
# REGEX(?paLabel, '^proteolytic', 'i') ||
# REGEX(?paLabel, '^phosphatases', 'i') ||
# REGEX(?paLabel, '^glycoprotein', 'i') ||
# REGEX(?paLabel, '^mono-adp-ribosylation', 'i') ||
# REGEX(?paLabel, '^secreting', 'i') ||
# REGEX(?paLabel, '^greater', 'i') ||
# REGEX(?paLabel, '^sporothrix', 'i') ||
# REGEX(?paLabel, '^inhibitors', 'i') ||
# REGEX(?paLabel, '^analytical', 'i') ||
# REGEX(?paLabel, '^pigs', 'i') ||
# REGEX(?paLabel, '^geographic', 'i') ||
# REGEX(?paLabel, '^tumour', 'i') ||
# REGEX(?paLabel, '^pedv', 'i') ||
# REGEX(?paLabel, '^repertoire', 'i') ||
# REGEX(?paLabel, '^distancing', 'i') ||
# REGEX(?paLabel, '^transcriptional', 'i') ||
# }
